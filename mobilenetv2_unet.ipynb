# %%
# !pip install scikit-image
# !pip install scikit-learn
# !pip install segmentation_models
# Out:
# Collecting scikit-image
#   Using cached scikit_image-0.19.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
# Collecting PyWavelets>=1.1.1
#   Using cached PyWavelets-1.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
# Requirement already satisfied: numpy>=1.17.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-image) (1.21.6)
# Collecting tifffile>=2019.7.26
#   Using cached tifffile-2022.10.10-py3-none-any.whl (210 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-image) (21.3)
# Collecting networkx>=2.2
#   Using cached networkx-2.8.8-py3-none-any.whl (2.0 MB)
# Collecting scipy>=1.4.1
#   Using cached scipy-1.9.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
# Collecting imageio>=2.4.1
#   Using cached imageio-2.22.4-py3-none-any.whl (3.4 MB)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-image) (9.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from packaging>=20.0->scikit-image) (3.0.9)
# Installing collected packages: tifffile, scipy, PyWavelets, networkx, imageio, scikit-image
# Successfully installed PyWavelets-1.4.1 imageio-2.22.4 networkx-2.8.8 scikit-image-0.19.3 scipy-1.9.3 tifffile-2022.10.10
# Collecting scikit-learn
#   Using cached scikit_learn-1.1.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.8 MB)
# Requirement already satisfied: numpy>=1.17.3 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-learn) (1.21.6)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy>=1.3.2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-learn) (1.9.3)
# Collecting joblib>=1.0.0
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.1.3 threadpoolctl-3.1.0
# Collecting segmentation_models
#   Using cached segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting efficientnet==1.0.0
#   Using cached efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7
#   Using cached Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
# Collecting image-classifiers==1.0.0
#   Using cached image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: scikit-image in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from efficientnet==1.0.0->segmentation_models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (1.21.6)
# Requirement already satisfied: h5py in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (3.7.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.9.3)
# Requirement already satisfied: packaging>=20.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (21.3)
# Requirement already satisfied: imageio>=2.4.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2.22.4)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (9.2.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2022.10.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.4.1)
# Requirement already satisfied: networkx>=2.2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2.8.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from packaging>=20.0->scikit-image->efficientnet==1.0.0->segmentation_models) (3.0.9)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation_models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation_models-1.0.1

# %%
import os

import keras
import matplotlib.pyplot as plt
import numpy as np
import segmentation_models as sm
from keras import optimizers, utils
from keras.models import Model

integer_to_class = {
    "1": "meningioma (1)",
    "2": "glioma (2)",
    "3": "pituitary tumor (3)",
}

##Load images, labels, masks
labels = np.load("dataset/labels.npy")
images = np.clip((np.load("dataset/images.npy") / 12728), 0, 1)
masks = np.load("dataset/masks.npy") * 1
print(labels.shape)
print(images.shape)
print(masks.shape)
# Out:
# 2022-11-22 07:36:17.813698: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Segmentation Models: using `keras` framework.
# (3064,)
# (3064, 512, 512)
# (3064, 512, 512)

# %%
from skimage.transform import resize

img_size_ori = 512
img_size_target = 128


def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(
        img,
        (img_size_target, img_size_target),
        mode="constant",
        preserve_range=True,
    )


def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(
        img, (img_size_ori, img_size_ori), mode="constant", preserve_range=True
    )


images = np.array([downsample(image) for image in images])
masks = (np.array([downsample(mask) for mask in masks]) > 0) * 1

print(images.shape)
print(masks.shape)
# Out:
# (3064, 128, 128)
# (3064, 128, 128)

# %%
classes, counts = np.unique(labels, return_counts=True)
plt.bar(classes, counts, tick_label=list(integer_to_class.values()))
print(counts)
# Out:
# [ 708 1426  930]

# %%
plt.figure(figsize=(12, 5))
for i, idx in enumerate(np.random.randint(images.shape[0], size=18), start=1):
    plt.subplot(3, 6, i)
    plt.imshow(images[idx], cmap="gray")
    plt.imshow(np.ones_like(masks[idx]) - masks[idx], alpha=0.5, cmap="Set1")
    plt.title(integer_to_class[str(labels[idx])])
    plt.axis("off")

# %% [markdown]
# ### Train Image and its mask which is to be predicted

# %%
plt.figure(figsize=(12, 5))
i = 1
for idx in np.random.randint(images.shape[0], size=9):
    plt.subplot(3, 6, i)
    i += 1
    plt.imshow(images[idx])
    plt.title("Train Image")
    plt.axis("off")
    plt.subplot(3, 6, i)
    i += 1
    plt.imshow(masks[idx])
    plt.title("Train Mask")
    plt.axis("off")

# %%
from keras.utils import normalize

###############################################
# Encode labels... but multi dim array so need to flatten, encode and reshape
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()
n, h, w = masks.shape
masks_reshaped = masks.reshape(-1, 1)
masks_reshaped_encoded = labelencoder.fit_transform(masks_reshaped)
masks_encoded_original_shape = masks_reshaped_encoded.reshape(n, h, w)

np.unique(masks_encoded_original_shape)
masks_input = masks_encoded_original_shape
# Out:
# /opt/saturncloud/envs/saturn/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
import gc

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    images, masks_input, test_size=0.2, random_state=0
)

x_train = np.repeat(x_train[..., np.newaxis], 3, axis=-1)

del images
del masks
del labels
gc.collect()
x_train.shape, x_train.shape
# Out:
# ((2451, 128, 128, 3), (2451, 128, 128, 3))

# %% [markdown]
# ### Augmentation

# %%
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(y) for y in y_train], axis=0)
x_train.shape
# Out:
# (4902, 128, 128, 3)

# %%
from keras.utils import to_categorical

y_train_cat = to_categorical(y_train, 3)
y_test_cat = to_categorical(y_test, 3)

print(y_train_cat.shape)
print(y_test_cat.shape)
# Out:
# (4902, 128, 128, 3)
# (613, 128, 128, 3)

# %%
######################################################
# Reused parameters in all models

n_classes = 3
activation = "softmax"
LR = 0.0001

optim = optimizers.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
# set class weights for dice_loss (car: 1.; pedestrian: 2.; background: 0.5;)
dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss

metrics = [
    "accuracy",
    sm.metrics.IOUScore(threshold=0.5),
    sm.metrics.FScore(threshold=0.5),
]

# %%
########################################################################
###Model 1
BACKBONE = "inceptionresnetv2"
preprocess_input = sm.get_preprocessing(BACKBONE)

# preprocess input
x_train = preprocess_input(x_train)
# define model
model = sm.Unet(
    BACKBONE, encoder_weights="imagenet", classes=n_classes, activation=activation
)

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics=metrics)

print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d_203 (Conv2D)            (None, None, None,   864         ['input_2[0][0]']
#                                 32)
#
#  batch_normalization_203 (Batch  (None, None, None,   96         ['conv2d_203[0][0]']
#  Normalization)                 32)
#
#  activation_203 (Activation)    (None, None, None,   0           ['batch_normalization_203[0][0]']
#                                 32)
#
#  conv2d_204 (Conv2D)            (None, None, None,   9216        ['activation_203[0][0]']
#                                 32)
#
#  batch_normalization_204 (Batch  (None, None, None,   96         ['conv2d_204[0][0]']
#  Normalization)                 32)
#
#  activation_204 (Activation)    (None, None, None,   0           ['batch_normalization_204[0][0]']
#                                 32)
#
#  conv2d_205 (Conv2D)            (None, None, None,   18432       ['activation_204[0][0]']
#                                 64)
#
#  batch_normalization_205 (Batch  (None, None, None,   192        ['conv2d_205[0][0]']
#  Normalization)                 64)
#
#  activation_205 (Activation)    (None, None, None,   0           ['batch_normalization_205[0][0]']
#                                 64)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, None, None,   0          ['activation_205[0][0]']
#                                 64)
#
#  conv2d_206 (Conv2D)            (None, None, None,   5120        ['max_pooling2d_4[0][0]']
#                                 80)
#
#  batch_normalization_206 (Batch  (None, None, None,   240        ['conv2d_206[0][0]']
#  Normalization)                 80)
#
#  activation_206 (Activation)    (None, None, None,   0           ['batch_normalization_206[0][0]']
#                                 80)
#
#  conv2d_207 (Conv2D)            (None, None, None,   138240      ['activation_206[0][0]']
#                                 192)
#
#  batch_normalization_207 (Batch  (None, None, None,   576        ['conv2d_207[0][0]']
#  Normalization)                 192)
#
#  activation_207 (Activation)    (None, None, None,   0           ['batch_normalization_207[0][0]']
#                                 192)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, None, None,   0          ['activation_207[0][0]']
#                                 192)
#
#  conv2d_211 (Conv2D)            (None, None, None,   12288       ['max_pooling2d_5[0][0]']
#                                 64)
#
#  batch_normalization_211 (Batch  (None, None, None,   192        ['conv2d_211[0][0]']
#  Normalization)                 64)
#
#  activation_211 (Activation)    (None, None, None,   0           ['batch_normalization_211[0][0]']
#                                 64)
#
#  conv2d_209 (Conv2D)            (None, None, None,   9216        ['max_pooling2d_5[0][0]']
#                                 48)
#
#  conv2d_212 (Conv2D)            (None, None, None,   55296       ['activation_211[0][0]']
#                                 96)
#
#  batch_normalization_209 (Batch  (None, None, None,   144        ['conv2d_209[0][0]']
#  Normalization)                 48)
#
#  batch_normalization_212 (Batch  (None, None, None,   288        ['conv2d_212[0][0]']
#  Normalization)                 96)
#
#  activation_209 (Activation)    (None, None, None,   0           ['batch_normalization_209[0][0]']
#                                 48)
#
#  activation_212 (Activation)    (None, None, None,   0           ['batch_normalization_212[0][0]']
#                                 96)
#
#  average_pooling2d_1 (AveragePo  (None, None, None,   0          ['max_pooling2d_5[0][0]']
#  oling2D)                       192)
#
#  conv2d_208 (Conv2D)            (None, None, None,   18432       ['max_pooling2d_5[0][0]']
#                                 96)
#
#  conv2d_210 (Conv2D)            (None, None, None,   76800       ['activation_209[0][0]']
#                                 64)
#
#  conv2d_213 (Conv2D)            (None, None, None,   82944       ['activation_212[0][0]']
#                                 96)
#
#  conv2d_214 (Conv2D)            (None, None, None,   12288       ['average_pooling2d_1[0][0]']
#                                 64)
#
#  batch_normalization_208 (Batch  (None, None, None,   288        ['conv2d_208[0][0]']
#  Normalization)                 96)
#
#  batch_normalization_210 (Batch  (None, None, None,   192        ['conv2d_210[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_213 (Batch  (None, None, None,   288        ['conv2d_213[0][0]']
#  Normalization)                 96)
#
#  batch_normalization_214 (Batch  (None, None, None,   192        ['conv2d_214[0][0]']
#  Normalization)                 64)
#
#  activation_208 (Activation)    (None, None, None,   0           ['batch_normalization_208[0][0]']
#                                 96)
#
#  activation_210 (Activation)    (None, None, None,   0           ['batch_normalization_210[0][0]']
#                                 64)
#
#  activation_213 (Activation)    (None, None, None,   0           ['batch_normalization_213[0][0]']
#                                 96)
#
#  activation_214 (Activation)    (None, None, None,   0           ['batch_normalization_214[0][0]']
#                                 64)
#
#  mixed_5b (Concatenate)         (None, None, None,   0           ['activation_208[0][0]',
#                                 320)                              'activation_210[0][0]',
#                                                                   'activation_213[0][0]',
#                                                                   'activation_214[0][0]']
#
#  conv2d_218 (Conv2D)            (None, None, None,   10240       ['mixed_5b[0][0]']
#                                 32)
#
#  batch_normalization_218 (Batch  (None, None, None,   96         ['conv2d_218[0][0]']
#  Normalization)                 32)
#
#  activation_218 (Activation)    (None, None, None,   0           ['batch_normalization_218[0][0]']
#                                 32)
#
#  conv2d_216 (Conv2D)            (None, None, None,   10240       ['mixed_5b[0][0]']
#                                 32)
#
#  conv2d_219 (Conv2D)            (None, None, None,   13824       ['activation_218[0][0]']
#                                 48)
#
#  batch_normalization_216 (Batch  (None, None, None,   96         ['conv2d_216[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_219 (Batch  (None, None, None,   144        ['conv2d_219[0][0]']
#  Normalization)                 48)
#
#  activation_216 (Activation)    (None, None, None,   0           ['batch_normalization_216[0][0]']
#                                 32)
#
#  activation_219 (Activation)    (None, None, None,   0           ['batch_normalization_219[0][0]']
#                                 48)
#
#  conv2d_215 (Conv2D)            (None, None, None,   10240       ['mixed_5b[0][0]']
#                                 32)
#
#  conv2d_217 (Conv2D)            (None, None, None,   9216        ['activation_216[0][0]']
#                                 32)
#
#  conv2d_220 (Conv2D)            (None, None, None,   27648       ['activation_219[0][0]']
#                                 64)
#
#  batch_normalization_215 (Batch  (None, None, None,   96         ['conv2d_215[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_217 (Batch  (None, None, None,   96         ['conv2d_217[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_220 (Batch  (None, None, None,   192        ['conv2d_220[0][0]']
#  Normalization)                 64)
#
#  activation_215 (Activation)    (None, None, None,   0           ['batch_normalization_215[0][0]']
#                                 32)
#
#  activation_217 (Activation)    (None, None, None,   0           ['batch_normalization_217[0][0]']
#                                 32)
#
#  activation_220 (Activation)    (None, None, None,   0           ['batch_normalization_220[0][0]']
#                                 64)
#
#  block35_1_mixed (Concatenate)  (None, None, None,   0           ['activation_215[0][0]',
#                                 128)                              'activation_217[0][0]',
#                                                                   'activation_220[0][0]']
#
#  block35_1_conv (Conv2D)        (None, None, None,   41280       ['block35_1_mixed[0][0]']
#                                 320)
#
#  block35_1 (Lambda)             (None, None, None,   0           ['mixed_5b[0][0]',
#                                 320)                              'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, None, None,   0           ['block35_1[0][0]']
#                                 320)
#
#  conv2d_224 (Conv2D)            (None, None, None,   10240       ['block35_1_ac[0][0]']
#                                 32)
#
#  batch_normalization_224 (Batch  (None, None, None,   96         ['conv2d_224[0][0]']
#  Normalization)                 32)
#
#  activation_224 (Activation)    (None, None, None,   0           ['batch_normalization_224[0][0]']
#                                 32)
#
#  conv2d_222 (Conv2D)            (None, None, None,   10240       ['block35_1_ac[0][0]']
#                                 32)
#
#  conv2d_225 (Conv2D)            (None, None, None,   13824       ['activation_224[0][0]']
#                                 48)
#
#  batch_normalization_222 (Batch  (None, None, None,   96         ['conv2d_222[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_225 (Batch  (None, None, None,   144        ['conv2d_225[0][0]']
#  Normalization)                 48)
#
#  activation_222 (Activation)    (None, None, None,   0           ['batch_normalization_222[0][0]']
#                                 32)
#
#  activation_225 (Activation)    (None, None, None,   0           ['batch_normalization_225[0][0]']
#                                 48)
#
#  conv2d_221 (Conv2D)            (None, None, None,   10240       ['block35_1_ac[0][0]']
#                                 32)
#
#  conv2d_223 (Conv2D)            (None, None, None,   9216        ['activation_222[0][0]']
#                                 32)
#
#  conv2d_226 (Conv2D)            (None, None, None,   27648       ['activation_225[0][0]']
#                                 64)
#
#  batch_normalization_221 (Batch  (None, None, None,   96         ['conv2d_221[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_223 (Batch  (None, None, None,   96         ['conv2d_223[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_226 (Batch  (None, None, None,   192        ['conv2d_226[0][0]']
#  Normalization)                 64)
#
#  activation_221 (Activation)    (None, None, None,   0           ['batch_normalization_221[0][0]']
#                                 32)
#
#  activation_223 (Activation)    (None, None, None,   0           ['batch_normalization_223[0][0]']
#                                 32)
#
#  activation_226 (Activation)    (None, None, None,   0           ['batch_normalization_226[0][0]']
#                                 64)
#
#  block35_2_mixed (Concatenate)  (None, None, None,   0           ['activation_221[0][0]',
#                                 128)                              'activation_223[0][0]',
#                                                                   'activation_226[0][0]']
#
#  block35_2_conv (Conv2D)        (None, None, None,   41280       ['block35_2_mixed[0][0]']
#                                 320)
#
#  block35_2 (Lambda)             (None, None, None,   0           ['block35_1_ac[0][0]',
#                                 320)                              'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, None, None,   0           ['block35_2[0][0]']
#                                 320)
#
#  conv2d_230 (Conv2D)            (None, None, None,   10240       ['block35_2_ac[0][0]']
#                                 32)
#
#  batch_normalization_230 (Batch  (None, None, None,   96         ['conv2d_230[0][0]']
#  Normalization)                 32)
#
#  activation_230 (Activation)    (None, None, None,   0           ['batch_normalization_230[0][0]']
#                                 32)
#
#  conv2d_228 (Conv2D)            (None, None, None,   10240       ['block35_2_ac[0][0]']
#                                 32)
#
#  conv2d_231 (Conv2D)            (None, None, None,   13824       ['activation_230[0][0]']
#                                 48)
#
#  batch_normalization_228 (Batch  (None, None, None,   96         ['conv2d_228[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_231 (Batch  (None, None, None,   144        ['conv2d_231[0][0]']
#  Normalization)                 48)
#
#  activation_228 (Activation)    (None, None, None,   0           ['batch_normalization_228[0][0]']
#                                 32)
#
#  activation_231 (Activation)    (None, None, None,   0           ['batch_normalization_231[0][0]']
#                                 48)
#
#  conv2d_227 (Conv2D)            (None, None, None,   10240       ['block35_2_ac[0][0]']
#                                 32)
#
#  conv2d_229 (Conv2D)            (None, None, None,   9216        ['activation_228[0][0]']
#                                 32)
#
#  conv2d_232 (Conv2D)            (None, None, None,   27648       ['activation_231[0][0]']
#                                 64)
#
#  batch_normalization_227 (Batch  (None, None, None,   96         ['conv2d_227[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_229 (Batch  (None, None, None,   96         ['conv2d_229[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_232 (Batch  (None, None, None,   192        ['conv2d_232[0][0]']
#  Normalization)                 64)
#
#  activation_227 (Activation)    (None, None, None,   0           ['batch_normalization_227[0][0]']
#                                 32)
#
#  activation_229 (Activation)    (None, None, None,   0           ['batch_normalization_229[0][0]']
#                                 32)
#
#  activation_232 (Activation)    (None, None, None,   0           ['batch_normalization_232[0][0]']
#                                 64)
#
#  block35_3_mixed (Concatenate)  (None, None, None,   0           ['activation_227[0][0]',
#                                 128)                              'activation_229[0][0]',
#                                                                   'activation_232[0][0]']
#
#  block35_3_conv (Conv2D)        (None, None, None,   41280       ['block35_3_mixed[0][0]']
#                                 320)
#
#  block35_3 (Lambda)             (None, None, None,   0           ['block35_2_ac[0][0]',
#                                 320)                              'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, None, None,   0           ['block35_3[0][0]']
#                                 320)
#
#  conv2d_236 (Conv2D)            (None, None, None,   10240       ['block35_3_ac[0][0]']
#                                 32)
#
#  batch_normalization_236 (Batch  (None, None, None,   96         ['conv2d_236[0][0]']
#  Normalization)                 32)
#
#  activation_236 (Activation)    (None, None, None,   0           ['batch_normalization_236[0][0]']
#                                 32)
#
#  conv2d_234 (Conv2D)            (None, None, None,   10240       ['block35_3_ac[0][0]']
#                                 32)
#
#  conv2d_237 (Conv2D)            (None, None, None,   13824       ['activation_236[0][0]']
#                                 48)
#
#  batch_normalization_234 (Batch  (None, None, None,   96         ['conv2d_234[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_237 (Batch  (None, None, None,   144        ['conv2d_237[0][0]']
#  Normalization)                 48)
#
#  activation_234 (Activation)    (None, None, None,   0           ['batch_normalization_234[0][0]']
#                                 32)
#
#  activation_237 (Activation)    (None, None, None,   0           ['batch_normalization_237[0][0]']
#                                 48)
#
#  conv2d_233 (Conv2D)            (None, None, None,   10240       ['block35_3_ac[0][0]']
#                                 32)
#
#  conv2d_235 (Conv2D)            (None, None, None,   9216        ['activation_234[0][0]']
#                                 32)
#
#  conv2d_238 (Conv2D)            (None, None, None,   27648       ['activation_237[0][0]']
#                                 64)
#
#  batch_normalization_233 (Batch  (None, None, None,   96         ['conv2d_233[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_235 (Batch  (None, None, None,   96         ['conv2d_235[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_238 (Batch  (None, None, None,   192        ['conv2d_238[0][0]']
#  Normalization)                 64)
#
#  activation_233 (Activation)    (None, None, None,   0           ['batch_normalization_233[0][0]']
#                                 32)
#
#  activation_235 (Activation)    (None, None, None,   0           ['batch_normalization_235[0][0]']
#                                 32)
#
#  activation_238 (Activation)    (None, None, None,   0           ['batch_normalization_238[0][0]']
#                                 64)
#
#  block35_4_mixed (Concatenate)  (None, None, None,   0           ['activation_233[0][0]',
#                                 128)                              'activation_235[0][0]',
#                                                                   'activation_238[0][0]']
#
#  block35_4_conv (Conv2D)        (None, None, None,   41280       ['block35_4_mixed[0][0]']
#                                 320)
#
#  block35_4 (Lambda)             (None, None, None,   0           ['block35_3_ac[0][0]',
#                                 320)                              'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, None, None,   0           ['block35_4[0][0]']
#                                 320)
#
#  conv2d_242 (Conv2D)            (None, None, None,   10240       ['block35_4_ac[0][0]']
#                                 32)
#
#  batch_normalization_242 (Batch  (None, None, None,   96         ['conv2d_242[0][0]']
#  Normalization)                 32)
#
#  activation_242 (Activation)    (None, None, None,   0           ['batch_normalization_242[0][0]']
#                                 32)
#
#  conv2d_240 (Conv2D)            (None, None, None,   10240       ['block35_4_ac[0][0]']
#                                 32)
#
#  conv2d_243 (Conv2D)            (None, None, None,   13824       ['activation_242[0][0]']
#                                 48)
#
#  batch_normalization_240 (Batch  (None, None, None,   96         ['conv2d_240[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_243 (Batch  (None, None, None,   144        ['conv2d_243[0][0]']
#  Normalization)                 48)
#
#  activation_240 (Activation)    (None, None, None,   0           ['batch_normalization_240[0][0]']
#                                 32)
#
#  activation_243 (Activation)    (None, None, None,   0           ['batch_normalization_243[0][0]']
#                                 48)
#
#  conv2d_239 (Conv2D)            (None, None, None,   10240       ['block35_4_ac[0][0]']
#                                 32)
#
#  conv2d_241 (Conv2D)            (None, None, None,   9216        ['activation_240[0][0]']
#                                 32)
#
#  conv2d_244 (Conv2D)            (None, None, None,   27648       ['activation_243[0][0]']
#                                 64)
#
#  batch_normalization_239 (Batch  (None, None, None,   96         ['conv2d_239[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_241 (Batch  (None, None, None,   96         ['conv2d_241[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_244 (Batch  (None, None, None,   192        ['conv2d_244[0][0]']
#  Normalization)                 64)
#
#  activation_239 (Activation)    (None, None, None,   0           ['batch_normalization_239[0][0]']
#                                 32)
#
#  activation_241 (Activation)    (None, None, None,   0           ['batch_normalization_241[0][0]']
#                                 32)
#
#  activation_244 (Activation)    (None, None, None,   0           ['batch_normalization_244[0][0]']
#                                 64)
#
#  block35_5_mixed (Concatenate)  (None, None, None,   0           ['activation_239[0][0]',
#                                 128)                              'activation_241[0][0]',
#                                                                   'activation_244[0][0]']
#
#  block35_5_conv (Conv2D)        (None, None, None,   41280       ['block35_5_mixed[0][0]']
#                                 320)
#
#  block35_5 (Lambda)             (None, None, None,   0           ['block35_4_ac[0][0]',
#                                 320)                              'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, None, None,   0           ['block35_5[0][0]']
#                                 320)
#
#  conv2d_248 (Conv2D)            (None, None, None,   10240       ['block35_5_ac[0][0]']
#                                 32)
#
#  batch_normalization_248 (Batch  (None, None, None,   96         ['conv2d_248[0][0]']
#  Normalization)                 32)
#
#  activation_248 (Activation)    (None, None, None,   0           ['batch_normalization_248[0][0]']
#                                 32)
#
#  conv2d_246 (Conv2D)            (None, None, None,   10240       ['block35_5_ac[0][0]']
#                                 32)
#
#  conv2d_249 (Conv2D)            (None, None, None,   13824       ['activation_248[0][0]']
#                                 48)
#
#  batch_normalization_246 (Batch  (None, None, None,   96         ['conv2d_246[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_249 (Batch  (None, None, None,   144        ['conv2d_249[0][0]']
#  Normalization)                 48)
#
# ...
#
#  batch_normalization_402 (Batch  (None, None, None,   576        ['conv2d_402[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_405 (Batch  (None, None, None,   768        ['conv2d_405[0][0]']
#  Normalization)                 256)
#
#  activation_402 (Activation)    (None, None, None,   0           ['batch_normalization_402[0][0]']
#                                 192)
#
#  activation_405 (Activation)    (None, None, None,   0           ['batch_normalization_405[0][0]']
#                                 256)
#
#  block8_10_mixed (Concatenate)  (None, None, None,   0           ['activation_402[0][0]',
#                                 448)                              'activation_405[0][0]']
#
#  block8_10_conv (Conv2D)        (None, None, None,   933920      ['block8_10_mixed[0][0]']
#                                 2080)
#
#  block8_10 (Lambda)             (None, None, None,   0           ['block8_9_ac[0][0]',
#                                 2080)                             'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, None, None,   3194880     ['block8_10[0][0]']
#                                 1536)
#
#  conv_7b_bn (BatchNormalization  (None, None, None,   4608       ['conv_7b[0][0]']
#  )                              1536)
#
#  conv_7b_ac (Activation)        (None, None, None,   0           ['conv_7b_bn[0][0]']
#                                 1536)
#
#  decoder_stage0_upsampling (UpS  (None, None, None,   0          ['conv_7b_ac[0][0]']
#  ampling2D)                     1536)
#
#  decoder_stage0_concat (Concate  (None, None, None,   0          ['decoder_stage0_upsampling[0][0]
#  nate)                          2624)                            ',
#                                                                   'block17_20_ac[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, None, None,   6045696     ['decoder_stage0_concat[0][0]']
#                                 256)
#
#  decoder_stage0a_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0a_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0a_relu (Activati  (None, None, None,   0          ['decoder_stage0a_bn[0][0]']
#  on)                            256)
#
#  decoder_stage0b_conv (Conv2D)  (None, None, None,   589824      ['decoder_stage0a_relu[0][0]']
#                                 256)
#
#  decoder_stage0b_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0b_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0b_relu (Activati  (None, None, None,   0          ['decoder_stage0b_bn[0][0]']
#  on)                            256)
#
#  decoder_stage1_upsampling (UpS  (None, None, None,   0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)                     256)
#
#  decoder_stage1_concat (Concate  (None, None, None,   0          ['decoder_stage1_upsampling[0][0]
#  nate)                          576)                             ',
#                                                                   'block35_10_ac[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, None, None,   663552      ['decoder_stage1_concat[0][0]']
#                                 128)
#
#  decoder_stage1a_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1a_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1a_relu (Activati  (None, None, None,   0          ['decoder_stage1a_bn[0][0]']
#  on)                            128)
#
#  decoder_stage1b_conv (Conv2D)  (None, None, None,   147456      ['decoder_stage1a_relu[0][0]']
#                                 128)
#
#  decoder_stage1b_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1b_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1b_relu (Activati  (None, None, None,   0          ['decoder_stage1b_bn[0][0]']
#  on)                            128)
#
#  decoder_stage2_upsampling (UpS  (None, None, None,   0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)                     128)
#
#  decoder_stage2_concat (Concate  (None, None, None,   0          ['decoder_stage2_upsampling[0][0]
#  nate)                          320)                             ',
#                                                                   'activation_207[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, None, None,   184320      ['decoder_stage2_concat[0][0]']
#                                 64)
#
#  decoder_stage2a_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2a_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2a_relu (Activati  (None, None, None,   0          ['decoder_stage2a_bn[0][0]']
#  on)                            64)
#
#  decoder_stage2b_conv (Conv2D)  (None, None, None,   36864       ['decoder_stage2a_relu[0][0]']
#                                 64)
#
#  decoder_stage2b_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2b_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2b_relu (Activati  (None, None, None,   0          ['decoder_stage2b_bn[0][0]']
#  on)                            64)
#
#  decoder_stage3_upsampling (UpS  (None, None, None,   0          ['decoder_stage2b_relu[0][0]']
#  ampling2D)                     64)
#
#  decoder_stage3_concat (Concate  (None, None, None,   0          ['decoder_stage3_upsampling[0][0]
#  nate)                          128)                             ',
#                                                                   'activation_205[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, None, None,   36864       ['decoder_stage3_concat[0][0]']
#                                 32)
#
#  decoder_stage3a_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3a_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3a_relu (Activati  (None, None, None,   0          ['decoder_stage3a_bn[0][0]']
#  on)                            32)
#
#  decoder_stage3b_conv (Conv2D)  (None, None, None,   9216        ['decoder_stage3a_relu[0][0]']
#                                 32)
#
#  decoder_stage3b_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3b_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3b_relu (Activati  (None, None, None,   0          ['decoder_stage3b_bn[0][0]']
#  on)                            32)
#
#  decoder_stage4_upsampling (UpS  (None, None, None,   0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     32)
#
#  decoder_stage4a_conv (Conv2D)  (None, None, None,   4608        ['decoder_stage4_upsampling[0][0]
#                                 16)                              ']
#
#  decoder_stage4a_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4a_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4a_relu (Activati  (None, None, None,   0          ['decoder_stage4a_bn[0][0]']
#  on)                            16)
#
#  decoder_stage4b_conv (Conv2D)  (None, None, None,   2304        ['decoder_stage4a_relu[0][0]']
#                                 16)
#
#  decoder_stage4b_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4b_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4b_relu (Activati  (None, None, None,   0          ['decoder_stage4b_bn[0][0]']
#  on)                            16)
#
#  final_conv (Conv2D)            (None, None, None,   435         ['decoder_stage4b_relu[0][0]']
#                                 3)
#
#  softmax (Activation)           (None, None, None,   0           ['final_conv[0][0]']
#                                 3)
#
# ==================================================================================================
# Total params: 62,061,843
# Trainable params: 61,999,315
# Non-trainable params: 62,528
# __________________________________________________________________________________________________
# None

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.preprocessing import LabelEncoder

model_checkpoint = ModelCheckpoint(
    "model_best_checkpoint.h5",
    save_best_only=True,
    monitor="val_loss",
    mode="min",
    verbose=1,
)
early_stopping = EarlyStopping(monitor="val_loss", patience=5, mode="min")
reduceLR = ReduceLROnPlateau(
    patience=4, verbose=2, monitor="val_loss", min_lr=1e-4, mode="min"
)

callback_list = [early_stopping, reduceLR, model_checkpoint]

hist = model.fit(
    x_train,
    y_train_cat,
    batch_size=32,
    epochs=100,
    validation_split=0.25,
    verbose=1,
    callbacks=callback_list,
)
# Out:
# Epoch 1/100
# 2022-11-22 07:42:30.545994: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2022-11-22 07:42:32.589713: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-22 07:42:32.590659: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-22 07:42:32.590700: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-11-22 07:42:32.591859: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-22 07:42:32.591960: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 115/115 [==============================] - ETA: 0s - loss: 0.7207 - accuracy: 0.8747 - iou_score: 0.4805 - f1-score: 0.5373
# Epoch 1: val_loss improved from inf to 0.75743, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 87s 512ms/step - loss: 0.7207 - accuracy: 0.8747 - iou_score: 0.4805 - f1-score: 0.5373 - val_loss: 0.7574 - val_accuracy: 0.9403 - val_iou_score: 0.1728 - val_f1-score: 0.2276 - lr: 1.0000e-04
# Epoch 2/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6557 - accuracy: 0.9170 - iou_score: 0.6868 - f1-score: 0.7372
# Epoch 2: val_loss improved from 0.75743 to 0.71150, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 50s 438ms/step - loss: 0.6557 - accuracy: 0.9170 - iou_score: 0.6868 - f1-score: 0.7372 - val_loss: 0.7115 - val_accuracy: 0.9651 - val_iou_score: 0.3128 - val_f1-score: 0.3227 - lr: 1.0000e-04
# Epoch 3/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6290 - accuracy: 0.9295 - iou_score: 0.6944 - f1-score: 0.7439
# Epoch 3: val_loss improved from 0.71150 to 0.69046, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 50s 440ms/step - loss: 0.6290 - accuracy: 0.9295 - iou_score: 0.6944 - f1-score: 0.7439 - val_loss: 0.6905 - val_accuracy: 0.9749 - val_iou_score: 0.6566 - val_f1-score: 0.6616 - lr: 1.0000e-04
# Epoch 4/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6144 - accuracy: 0.9354 - iou_score: 0.6978 - f1-score: 0.7466
# Epoch 4: val_loss improved from 0.69046 to 0.65275, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 51s 442ms/step - loss: 0.6144 - accuracy: 0.9354 - iou_score: 0.6978 - f1-score: 0.7466 - val_loss: 0.6527 - val_accuracy: 0.9130 - val_iou_score: 0.6839 - val_f1-score: 0.7341 - lr: 1.0000e-04
# Epoch 5/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6077 - accuracy: 0.9388 - iou_score: 0.6992 - f1-score: 0.7477
# Epoch 5: val_loss improved from 0.65275 to 0.62931, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 51s 446ms/step - loss: 0.6077 - accuracy: 0.9388 - iou_score: 0.6992 - f1-score: 0.7477 - val_loss: 0.6293 - val_accuracy: 0.9542 - val_iou_score: 0.6936 - val_f1-score: 0.7341 - lr: 1.0000e-04
# Epoch 6/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6039 - accuracy: 0.9405 - iou_score: 0.7002 - f1-score: 0.7485
# Epoch 6: val_loss did not improve from 0.62931
# 115/115 [==============================] - 46s 399ms/step - loss: 0.6039 - accuracy: 0.9405 - iou_score: 0.7002 - f1-score: 0.7485 - val_loss: 0.6801 - val_accuracy: 0.9749 - val_iou_score: 0.6584 - val_f1-score: 0.6625 - lr: 1.0000e-04
# Epoch 7/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6011 - accuracy: 0.9427 - iou_score: 0.7016 - f1-score: 0.7498
# Epoch 7: val_loss improved from 0.62931 to 0.62358, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 53s 465ms/step - loss: 0.6011 - accuracy: 0.9427 - iou_score: 0.7016 - f1-score: 0.7498 - val_loss: 0.6236 - val_accuracy: 0.9573 - val_iou_score: 0.6873 - val_f1-score: 0.7224 - lr: 1.0000e-04
# Epoch 8/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5989 - accuracy: 0.9440 - iou_score: 0.7029 - f1-score: 0.7513
# Epoch 8: val_loss did not improve from 0.62358
# 115/115 [==============================] - 47s 413ms/step - loss: 0.5989 - accuracy: 0.9440 - iou_score: 0.7029 - f1-score: 0.7513 - val_loss: 0.6732 - val_accuracy: 0.8944 - val_iou_score: 0.6688 - val_f1-score: 0.7159 - lr: 1.0000e-04
# Epoch 9/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5983 - accuracy: 0.9440 - iou_score: 0.7027 - f1-score: 0.7510
# Epoch 9: val_loss did not improve from 0.62358
# 115/115 [==============================] - 48s 415ms/step - loss: 0.5983 - accuracy: 0.9440 - iou_score: 0.7027 - f1-score: 0.7510 - val_loss: 0.6717 - val_accuracy: 0.8979 - val_iou_score: 0.6499 - val_f1-score: 0.6818 - lr: 1.0000e-04
# Epoch 10/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5984 - accuracy: 0.9444 - iou_score: 0.7026 - f1-score: 0.7507
# Epoch 10: val_loss did not improve from 0.62358
# 115/115 [==============================] - 48s 415ms/step - loss: 0.5984 - accuracy: 0.9444 - iou_score: 0.7026 - f1-score: 0.7507 - val_loss: 0.7045 - val_accuracy: 0.9749 - val_iou_score: 0.6584 - val_f1-score: 0.6625 - lr: 1.0000e-04
# Epoch 11/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5970 - accuracy: 0.9457 - iou_score: 0.7036 - f1-score: 0.7517
# Epoch 11: val_loss did not improve from 0.62358
# 115/115 [==============================] - 47s 413ms/step - loss: 0.5970 - accuracy: 0.9457 - iou_score: 0.7036 - f1-score: 0.7517 - val_loss: 0.7046 - val_accuracy: 0.9749 - val_iou_score: 0.6584 - val_f1-score: 0.6625 - lr: 1.0000e-04
# Epoch 12/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5960 - accuracy: 0.9459 - iou_score: 0.7041 - f1-score: 0.7525
# Epoch 12: val_loss did not improve from 0.62358
# 115/115 [==============================] - 47s 412ms/step - loss: 0.5960 - accuracy: 0.9459 - iou_score: 0.7041 - f1-score: 0.7525 - val_loss: 0.7212 - val_accuracy: 0.7523 - val_iou_score: 0.5999 - val_f1-score: 0.6514 - lr: 1.0000e-04

# %%
from keras.models import load_model
model = load_model('model_best_checkpoint.h5', compile=False) #or compile = False

# %% [markdown]
# ### Plot graph of Dice Loss, IoU Metric, and Dice Coefficient

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 4))
t = f.suptitle('Model Performance in Segmenting Tumors', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)
epoch_list = hist.epoch

ax1.plot(epoch_list, hist.history['loss'], label='Train Dice Loss')
ax1.plot(epoch_list, hist.history['val_loss'], label='Val Dice Loss')
ax1.set_xticks(np.arange(0, epoch_list[-1], 5))
ax1.set_ylabel('Dice Loss Value');ax1.set_xlabel('Epoch');ax1.set_title('Dice Loss')
ax1.legend(loc="best");ax1.grid(color='gray', linestyle='-', linewidth=0.5)

ax2.plot(epoch_list, hist.history['f1-score'], label='Train Dice Coeff')
ax2.plot(epoch_list, hist.history['val_f1-score'], label='Val Dice Coeff')
ax2.set_xticks(np.arange(0, epoch_list[-1], 5))
ax2.set_ylabel('Dice Coefficient Value');ax2.set_xlabel('Epoch');ax2.set_title('Dice Coefficient')
ax2.legend(loc="best");ax2.grid(color='gray', linestyle='-', linewidth=0.5)

ax3.plot(epoch_list, hist.history['iou_score'], label='Train IOU metric')
ax3.plot(epoch_list, hist.history['val_iou_score'], label='Val IOU metric')
ax3.set_xticks(np.arange(0, epoch_list[-1], 5))
ax3.set_ylabel('IOU metric');ax3.set_xlabel('Epoch');ax3.set_title('IOU metric')
ax3.legend(loc="best");ax3.grid(color='gray', linestyle='-', linewidth=0.5)

# %% [markdown]
# ### Determine IoU and Dice Coefficient for Threshold=0.5

# %%
def iou_metric(label, pred):
    return tf.numpy_function(get_iou_vector, [label, pred>THRESHOLD], tf.float64)

def dice_coefficient(y_true, y_pred):
    smooth = 1.
    y_true_f = tf.cast(K.flatten(y_true), tf.float32)
    y_pred_f = tf.cast(K.flatten(y_pred), tf.float32)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

def get_iou_vector(A, B):
    t = A > 0
    p = B > 0
    intersection = np.logical_and(t, p)
    union = np.logical_or(t, p)
    iou = (np.sum(intersection) + 1e-10) / (np.sum(union) + 1e-10)
    return iou

def getIOUCurve(mask_org,predicted):
  thresholds = np.linspace(0, 1, 100)
  ious = np.array([get_iou_vector(mask_org, predicted > threshold) for threshold in thresholds])
  thres_best_index = np.argmax(ious[9:-10]) + 9
  iou_best = ious[thres_best_index]
  thres_best = thresholds[thres_best_index]
  return thresholds,ious,iou_best,thres_best

# %%
x_test_pred = np.repeat(x_test[..., np.newaxis], 3, axis=-1)
x_test_pred = preprocess_input(x_test_pred)
import tensorflow as tf
from keras import backend as K
THRESHOLD = 0.5
pred_mask = model.predict(x_test_pred)
iou_score = iou_metric(y_test_cat, pred_mask)
dice_coeff = dice_coefficient(y_test_cat, pred_mask)
print("IoU score is: ", tf.get_static_value(iou_score))
print("Dice Coefficient is: ", tf.get_static_value(dice_coeff))
# Out:
# 20/20 [==============================] - 6s 152ms/step
# IoU score is:  0.9190092139369862
# Dice Coefficient is:  0.9400657

# %% [markdown]
# ### Predict Masks

# %%
x_test.shape
# Out:
# (613, 128, 128)

# %%
predicted_mask = pred_mask>THRESHOLD

plt.figure(figsize=(8,30))
i=1;total=10
temp = np.ones_like( y_test_cat[0] )
for idx in np.random.randint(0,high=x_test.shape[0],size=total):
    plt.subplot(total,3,i);i+=1
    plt.imshow( x_test[idx], cmap='gray' )
    plt.title("MRI Image");plt.axis('off')
    
    plt.subplot(total,3,i);i+=1
    plt.imshow( x_test[idx], cmap='gray' )
    plt.imshow( temp - y_test_cat[idx], alpha=0.2, cmap='Set1' )
    plt.title("Original Mask");plt.axis('off')
    
    plt.subplot(total,3,i);i+=1
    plt.imshow( x_test[idx], cmap='gray' )
    plt.imshow( temp - predicted_mask[idx],  alpha=0.2, cmap='Set1' )
    plt.title("Predicted Mask");plt.axis('off')

# %% [markdown]
# ### Plot IoU Curve using different Thresholds

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Model Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

th, ious, iou_best, th_best = getIOUCurve(y_test_cat,model.predict(x_test_pred))
ax1.plot(th, ious,label="For Validation")
ax1.plot(th_best, iou_best, "xr", label="Best threshold")
ax1.set_ylabel('IOU');ax1.set_xlabel('Threshold')
ax1.set_title("Threshold vs IoU ({}, {})".format(round(th_best, 4), round(iou_best, 4)))

th, ious, iou_best, th_best = getIOUCurve(y_train_cat,model.predict(x_train))
ax2.plot(th, ious, label="For Training")
ax2.plot(th_best, iou_best, "xr", label="Best threshold")
ax2.set_ylabel('IOU');ax2.set_xlabel('Threshold')
ax2.set_title("Threshold vs IoU ({}, {})".format(round(th_best, 4), round(iou_best, 4)))
# Out:
# 20/20 [==============================] - 2s 102ms/step
# 154/154 [==============================] - 17s 110ms/step
# Text(0.5, 1.0, 'Threshold vs IoU (0.4949, 0.9172)')
