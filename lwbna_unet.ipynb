# %%
# !pip install hdf5storage
# !git clone https://github.com/adityajn105/brain-tumor-segmentation-unet
# !bash tumor-segmentation-unet/download_data.sh
# !python mat_to_numpy.py brain_tumor_dataset/
# !pip install scikit-image
# !pip install scikit-learn
# Out:
# Collecting scikit-image
#   Using cached scikit_image-0.19.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
# Collecting scipy>=1.4.1
#   Using cached scipy-1.9.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-image) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-image) (21.3)
# Collecting imageio>=2.4.1
#   Using cached imageio-2.22.4-py3-none-any.whl (3.4 MB)
# Requirement already satisfied: numpy>=1.17.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-image) (1.21.6)
# Collecting networkx>=2.2
#   Using cached networkx-2.8.8-py3-none-any.whl (2.0 MB)
# Collecting PyWavelets>=1.1.1
#   Using cached PyWavelets-1.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
# Collecting tifffile>=2019.7.26
#   Using cached tifffile-2022.10.10-py3-none-any.whl (210 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from packaging>=20.0->scikit-image) (3.0.9)
# Installing collected packages: tifffile, scipy, PyWavelets, networkx, imageio, scikit-image
# Successfully installed PyWavelets-1.4.1 imageio-2.22.4 networkx-2.8.8 scikit-image-0.19.3 scipy-1.9.3 tifffile-2022.10.10
# Collecting scikit-learn
#   Using cached scikit_learn-1.1.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.8 MB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.17.3 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-learn) (1.21.6)
# Collecting joblib>=1.0.0
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: scipy>=1.3.2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-learn) (1.9.3)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.1.3 threadpoolctl-3.1.0

# %%
# import zipfile as zf

# files = zf.ZipFile("dataset.zip",'r')
# files.extractall()
# files.close()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

integer_to_class = {'1': 'meningioma (1)', '2': 'glioma (2)', '3': 'pituitary tumor (3)'}

##Load images, labels, masks
labels = np.load('dataset/labels.npy')
images = np.clip( (np.load('dataset/images.npy')/12728),0,1)
masks = np.load('dataset/masks.npy')*1
print(labels.shape)
print(images.shape)
print(masks.shape)
# Out:
# (3064,)
# (3064, 512, 512)
# (3064, 512, 512)

# %%
from skimage.transform import resize
img_size_ori = 512
img_size_target = 128

images = np.expand_dims(images,axis=-1)
masks = np.expand_dims(masks,axis=-1)

def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True,)
    
def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)
  
images = np.array([ downsample(image) for image in images ])
masks = (np.array([ downsample(mask) for mask in masks ])>0)*1

print(images.shape)
print(masks.shape)
# Out:
# (3064, 128, 128, 1)
# (3064, 128, 128, 1)

# %%
classes, counts = np.unique(labels,return_counts=True)
plt.bar(classes,counts,tick_label=list(integer_to_class.values()))
print(counts)
# Out:
# [ 708 1426  930]

# %%
plt.figure(figsize=(12, 5))
for i, idx in enumerate(np.random.randint(images.shape[0], size=18), start=1):
    plt.subplot(3, 6, i)
    plt.imshow( np.squeeze(images[idx],axis=-1), cmap='gray')
    plt.imshow( np.squeeze(np.ones_like(masks[idx])-masks[idx],axis=-1), alpha=0.5, cmap='Set1')
    plt.title(integer_to_class[str(labels[idx])])
    plt.axis('off')

# %% [markdown]
# ### Train Image and its mask which is to be predicted

# %%
plt.figure(figsize=(12, 5))
i=1
for idx in np.random.randint( images.shape[0], size=9):
  plt.subplot(3,6,i);i+=1
  plt.imshow( np.squeeze(images[idx],axis=-1))
  plt.title("Train Image")
  plt.axis('off')
  plt.subplot(3,6,i);i+=1
  plt.imshow( np.squeeze(masks[idx],axis=-1)) 
  plt.title("Train Mask")
  plt.axis('off')

# %%
from sklearn.model_selection import train_test_split
import gc
X,X_v,Y,Y_v = train_test_split( images,masks,test_size=0.2,stratify=labels)
del images
del masks
del labels
gc.collect()
X.shape,X_v.shape
# Out:
# ((2451, 128, 128, 1), (613, 128, 128, 1))

# %% [markdown]
# ### Augmentation

# %%
X = np.append( X, [ np.fliplr(x) for x in X], axis=0 )
Y = np.append( Y, [ np.fliplr(y) for y in Y], axis=0 )
X.shape,Y.shape
# Out:
# ((4902, 128, 128, 1), (4902, 128, 128, 1))

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(brightness_range=(0.9,1.1),
                                   zoom_range=[.9,1.1],
                                   fill_mode='nearest')
val_datagen = ImageDataGenerator()
# Out:
# 2022-11-18 17:17:35.851033: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# ### Defining the Model

# %%
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Add, Dropout, Input, BatchNormalization, GlobalAveragePooling2D, Dense, Multiply
from keras import optimizers
from keras.models import Model
import tensorflow as tf

IMG_DIM = (128,128,1)

def conv2d_block( input_tensor, n_filters, kernel_size = (3,3), name="contraction"):
    
    "Add 2 conv layer"
    x = Conv2D(filters=n_filters, kernel_size=kernel_size, kernel_initializer='he_normal', 
             padding='same',activation="relu", name=name+'_1')(input_tensor)
    
    x = BatchNormalization(momentum=0.8)(x)
  
    x = Conv2D(filters=n_filters, kernel_size=kernel_size, kernel_initializer='he_normal', 
             padding='same',activation="relu",name=name+'_2')(x)
    
    x = BatchNormalization(momentum=0.8)(x)
    return x

def attn_block( input_tensor, units):
    
    "Add global average pooling, fully connected layer, activation with ReLU and sigmoid functions, and multiplication of the resulting weights to each channel"
    
    x = GlobalAveragePooling2D()(input_tensor)
    
    x = Dense(units, activation="relu")(x)
    x = Dense(units, activation="sigmoid")(x)
    y = Dense(units,)(input_tensor)
    
    x = Multiply()([x, y])

    return x

def mid_block( input_tensor, n_filters, kernel_size = (3,3), name="midblock"):
    "Add global average pooling, fully connected layer, activation with ReLU and sigmoid functions, and multiplication of the resulting weights to each channel"
  
    a = Conv2D(filters=n_filters, kernel_size=kernel_size, kernel_initializer='he_normal', 
             padding='same',activation="relu", name=name+'_1')(input_tensor)
    
    x = attn_block( a, 128)
    x = attn_block( x, 64)
    x = attn_block( x, 32)
    x = attn_block( x, 16)
    
    x = Conv2D(filters=n_filters, kernel_size=kernel_size, kernel_initializer='he_normal', 
             padding='same',activation="relu", name=name+'_2')(x)
    
    x = Add()([a,x])

    return x
  

inp = Input( shape=IMG_DIM )

d1 = conv2d_block( inp, 128, name="contraction_1")
d1 = attn_block( d1, 128)
p1 = MaxPooling2D( pool_size=(2,2), strides=(2,2))(d1)

d2 = Dropout(0.3)(p1)
d2 = conv2d_block( d2, 128, name="contraction_2" )
d2 = attn_block( d2, 128)
p2 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d2)

d3 = Dropout(0.3)(p2)
d3 = conv2d_block( d3, 128, name="contraction_3" )
d3 = attn_block( d3, 128)
p3 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d3)

d4 = Dropout(0.3)(p3)
d4 = conv2d_block( d4, 128, name="contraction_4" )
d4 = attn_block( d4, 128)
p4 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d4)

d5 = Dropout(0.3)(p4)
d5 = mid_block( d5, 128 )
d5 = conv2d_block( d5, 128, name="expansion_1" )
d5 = attn_block( d5, 128)

u1 = UpSampling2D()(d5)
u1 = Add()([u1,d4])
c1 = Dropout(0.3)(u1)
c1 = conv2d_block(c1, 128, name="expansion_2")
c1 = attn_block( c1, 128)

u2 = UpSampling2D()(c1)
u2 = Add()([u2,d3])
c2 = Dropout(0.3)(u2)
c2 = conv2d_block(c2, 128, name="expansion_3")
c2 = attn_block( c2, 128)

u3 = UpSampling2D()(c2)
u3 = Add()([u3,d2])
c3 = Dropout(0.3)(u3)
c3 = conv2d_block(c3, 128, name="expansion_4")
c3 = attn_block( c3, 128)

u4 = UpSampling2D()(c3)
u4 = Add()([u4,d1])
c4 = Dropout(0.3)(u4)
c4 = conv2d_block(c4, 128, name="expansion_5")
c4 = attn_block( c4, 128)

out = Conv2D(1, (1,1), name="output", activation='sigmoid')(c4)

model = Model( inp, out )
model.summary()
# Out:
# 2022-11-18 17:17:43.445948: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 17:17:43.526827: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 17:17:43.527517: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 17:17:43.529181: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-18 17:17:43.530315: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 17:17:43.531206: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 17:17:43.532103: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 17:17:44.843512: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 17:17:44.844803: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 17:17:44.845417: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 17:17:44.845969: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13795 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  contraction_1_1 (Conv2D)       (None, 128, 128, 12  1280        ['input_1[0][0]']
#                                 8)
#
#  batch_normalization (BatchNorm  (None, 128, 128, 12  512        ['contraction_1_1[0][0]']
#  alization)                     8)
#
#  contraction_1_2 (Conv2D)       (None, 128, 128, 12  147584      ['batch_normalization[0][0]']
#                                 8)
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 12  512        ['contraction_1_2[0][0]']
#  rmalization)                   8)
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['batch_normalization_1[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 128)          16512       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 128)          16512       ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 128, 128, 12  16512       ['batch_normalization_1[0][0]']
#                                 8)
#
#  multiply (Multiply)            (None, 128, 128, 12  0           ['dense_1[0][0]',
#                                 8)                                'dense_2[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 128)  0           ['multiply[0][0]']
#
#  dropout (Dropout)              (None, 64, 64, 128)  0           ['max_pooling2d[0][0]']
#
#  contraction_2_1 (Conv2D)       (None, 64, 64, 128)  147584      ['dropout[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 128)  512        ['contraction_2_1[0][0]']
#  rmalization)
#
#  contraction_2_2 (Conv2D)       (None, 64, 64, 128)  147584      ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 128)  512        ['contraction_2_2[0][0]']
#  rmalization)
#
#  global_average_pooling2d_1 (Gl  (None, 128)         0           ['batch_normalization_3[0][0]']
#  obalAveragePooling2D)
#
#  dense_3 (Dense)                (None, 128)          16512       ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_4 (Dense)                (None, 128)          16512       ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 64, 64, 128)  16512       ['batch_normalization_3[0][0]']
#
#  multiply_1 (Multiply)          (None, 64, 64, 128)  0           ['dense_4[0][0]',
#                                                                   'dense_5[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0          ['multiply_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 128)  0           ['max_pooling2d_1[0][0]']
#
#  contraction_3_1 (Conv2D)       (None, 32, 32, 128)  147584      ['dropout_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 128)  512        ['contraction_3_1[0][0]']
#  rmalization)
#
#  contraction_3_2 (Conv2D)       (None, 32, 32, 128)  147584      ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 128)  512        ['contraction_3_2[0][0]']
#  rmalization)
#
#  global_average_pooling2d_2 (Gl  (None, 128)         0           ['batch_normalization_5[0][0]']
#  obalAveragePooling2D)
#
#  dense_6 (Dense)                (None, 128)          16512       ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_7 (Dense)                (None, 128)          16512       ['dense_6[0][0]']
#
#  dense_8 (Dense)                (None, 32, 32, 128)  16512       ['batch_normalization_5[0][0]']
#
#  multiply_2 (Multiply)          (None, 32, 32, 128)  0           ['dense_7[0][0]',
#                                                                   'dense_8[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0          ['multiply_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 128)  0           ['max_pooling2d_2[0][0]']
#
#  contraction_4_1 (Conv2D)       (None, 16, 16, 128)  147584      ['dropout_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 128)  512        ['contraction_4_1[0][0]']
#  rmalization)
#
#  contraction_4_2 (Conv2D)       (None, 16, 16, 128)  147584      ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 128)  512        ['contraction_4_2[0][0]']
#  rmalization)
#
#  global_average_pooling2d_3 (Gl  (None, 128)         0           ['batch_normalization_7[0][0]']
#  obalAveragePooling2D)
#
#  dense_9 (Dense)                (None, 128)          16512       ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  dense_10 (Dense)               (None, 128)          16512       ['dense_9[0][0]']
#
#  dense_11 (Dense)               (None, 16, 16, 128)  16512       ['batch_normalization_7[0][0]']
#
#  multiply_3 (Multiply)          (None, 16, 16, 128)  0           ['dense_10[0][0]',
#                                                                   'dense_11[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)   0           ['multiply_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 8, 8, 128)    0           ['max_pooling2d_3[0][0]']
#
#  midblock_1 (Conv2D)            (None, 8, 8, 128)    147584      ['dropout_3[0][0]']
#
#  global_average_pooling2d_4 (Gl  (None, 128)         0           ['midblock_1[0][0]']
#  obalAveragePooling2D)
#
#  dense_12 (Dense)               (None, 128)          16512       ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  dense_13 (Dense)               (None, 128)          16512       ['dense_12[0][0]']
#
#  dense_14 (Dense)               (None, 8, 8, 128)    16512       ['midblock_1[0][0]']
#
#  multiply_4 (Multiply)          (None, 8, 8, 128)    0           ['dense_13[0][0]',
#                                                                   'dense_14[0][0]']
#
#  global_average_pooling2d_5 (Gl  (None, 128)         0           ['multiply_4[0][0]']
#  obalAveragePooling2D)
#
#  dense_15 (Dense)               (None, 64)           8256        ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  dense_16 (Dense)               (None, 64)           4160        ['dense_15[0][0]']
#
#  dense_17 (Dense)               (None, 8, 8, 64)     8256        ['multiply_4[0][0]']
#
#  multiply_5 (Multiply)          (None, 8, 8, 64)     0           ['dense_16[0][0]',
#                                                                   'dense_17[0][0]']
#
#  global_average_pooling2d_6 (Gl  (None, 64)          0           ['multiply_5[0][0]']
#  obalAveragePooling2D)
#
#  dense_18 (Dense)               (None, 32)           2080        ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
#  dense_19 (Dense)               (None, 32)           1056        ['dense_18[0][0]']
#
#  dense_20 (Dense)               (None, 8, 8, 32)     2080        ['multiply_5[0][0]']
#
#  multiply_6 (Multiply)          (None, 8, 8, 32)     0           ['dense_19[0][0]',
#                                                                   'dense_20[0][0]']
#
#  global_average_pooling2d_7 (Gl  (None, 32)          0           ['multiply_6[0][0]']
#  obalAveragePooling2D)
#
#  dense_21 (Dense)               (None, 16)           528         ['global_average_pooling2d_7[0][0
#                                                                  ]']
#
#  dense_22 (Dense)               (None, 16)           272         ['dense_21[0][0]']
#
#  dense_23 (Dense)               (None, 8, 8, 16)     528         ['multiply_6[0][0]']
#
#  multiply_7 (Multiply)          (None, 8, 8, 16)     0           ['dense_22[0][0]',
#                                                                   'dense_23[0][0]']
#
#  midblock_2 (Conv2D)            (None, 8, 8, 128)    18560       ['multiply_7[0][0]']
#
#  add (Add)                      (None, 8, 8, 128)    0           ['midblock_1[0][0]',
#                                                                   'midblock_2[0][0]']
#
#  expansion_1_1 (Conv2D)         (None, 8, 8, 128)    147584      ['add[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 8, 128)   512         ['expansion_1_1[0][0]']
#  rmalization)
#
#  expansion_1_2 (Conv2D)         (None, 8, 8, 128)    147584      ['batch_normalization_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 8, 8, 128)   512         ['expansion_1_2[0][0]']
#  rmalization)
#
#  global_average_pooling2d_8 (Gl  (None, 128)         0           ['batch_normalization_9[0][0]']
#  obalAveragePooling2D)
#
#  dense_24 (Dense)               (None, 128)          16512       ['global_average_pooling2d_8[0][0
#                                                                  ]']
#
#  dense_25 (Dense)               (None, 128)          16512       ['dense_24[0][0]']
#
#  dense_26 (Dense)               (None, 8, 8, 128)    16512       ['batch_normalization_9[0][0]']
#
#  multiply_8 (Multiply)          (None, 8, 8, 128)    0           ['dense_25[0][0]',
#                                                                   'dense_26[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 128)  0           ['multiply_8[0][0]']
#
#  add_1 (Add)                    (None, 16, 16, 128)  0           ['up_sampling2d[0][0]',
#                                                                   'multiply_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 128)  0           ['add_1[0][0]']
#
#  expansion_2_1 (Conv2D)         (None, 16, 16, 128)  147584      ['dropout_4[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 128)  512        ['expansion_2_1[0][0]']
#  ormalization)
#
#  expansion_2_2 (Conv2D)         (None, 16, 16, 128)  147584      ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 128)  512        ['expansion_2_2[0][0]']
#  ormalization)
#
#  global_average_pooling2d_9 (Gl  (None, 128)         0           ['batch_normalization_11[0][0]']
#  obalAveragePooling2D)
#
#  dense_27 (Dense)               (None, 128)          16512       ['global_average_pooling2d_9[0][0
#                                                                  ]']
#
#  dense_28 (Dense)               (None, 128)          16512       ['dense_27[0][0]']
#
#  dense_29 (Dense)               (None, 16, 16, 128)  16512       ['batch_normalization_11[0][0]']
#
#  multiply_9 (Multiply)          (None, 16, 16, 128)  0           ['dense_28[0][0]',
#                                                                   'dense_29[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 128)  0          ['multiply_9[0][0]']
#
#  add_2 (Add)                    (None, 32, 32, 128)  0           ['up_sampling2d_1[0][0]',
#                                                                   'multiply_2[0][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 128)  0           ['add_2[0][0]']
#
#  expansion_3_1 (Conv2D)         (None, 32, 32, 128)  147584      ['dropout_5[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 128)  512        ['expansion_3_1[0][0]']
#  ormalization)
#
#  expansion_3_2 (Conv2D)         (None, 32, 32, 128)  147584      ['batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 128)  512        ['expansion_3_2[0][0]']
#  ormalization)
#
#  global_average_pooling2d_10 (G  (None, 128)         0           ['batch_normalization_13[0][0]']
#  lobalAveragePooling2D)
#
#  dense_30 (Dense)               (None, 128)          16512       ['global_average_pooling2d_10[0][
#                                                                  0]']
#
#  dense_31 (Dense)               (None, 128)          16512       ['dense_30[0][0]']
#
#  dense_32 (Dense)               (None, 32, 32, 128)  16512       ['batch_normalization_13[0][0]']
#
#  multiply_10 (Multiply)         (None, 32, 32, 128)  0           ['dense_31[0][0]',
#                                                                   'dense_32[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 128)  0          ['multiply_10[0][0]']
#
#  add_3 (Add)                    (None, 64, 64, 128)  0           ['up_sampling2d_2[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 128)  0           ['add_3[0][0]']
#
#  expansion_4_1 (Conv2D)         (None, 64, 64, 128)  147584      ['dropout_6[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 128)  512        ['expansion_4_1[0][0]']
#  ormalization)
#
#  expansion_4_2 (Conv2D)         (None, 64, 64, 128)  147584      ['batch_normalization_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 128)  512        ['expansion_4_2[0][0]']
#  ormalization)
#
#  global_average_pooling2d_11 (G  (None, 128)         0           ['batch_normalization_15[0][0]']
#  lobalAveragePooling2D)
#
#  dense_33 (Dense)               (None, 128)          16512       ['global_average_pooling2d_11[0][
#                                                                  0]']
#
#  dense_34 (Dense)               (None, 128)          16512       ['dense_33[0][0]']
#
#  dense_35 (Dense)               (None, 64, 64, 128)  16512       ['batch_normalization_15[0][0]']
#
#  multiply_11 (Multiply)         (None, 64, 64, 128)  0           ['dense_34[0][0]',
#                                                                   'dense_35[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 12  0          ['multiply_11[0][0]']
#                                 8)
#
#  add_4 (Add)                    (None, 128, 128, 12  0           ['up_sampling2d_3[0][0]',
#                                 8)                                'multiply[0][0]']
#
#  dropout_7 (Dropout)            (None, 128, 128, 12  0           ['add_4[0][0]']
#                                 8)
#
#  expansion_5_1 (Conv2D)         (None, 128, 128, 12  147584      ['dropout_7[0][0]']
#                                 8)
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 12  512        ['expansion_5_1[0][0]']
#  ormalization)                  8)
#
#  expansion_5_2 (Conv2D)         (None, 128, 128, 12  147584      ['batch_normalization_16[0][0]']
#                                 8)
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 12  512        ['expansion_5_2[0][0]']
#  ormalization)                  8)
#
#  global_average_pooling2d_12 (G  (None, 128)         0           ['batch_normalization_17[0][0]']
#  lobalAveragePooling2D)
#
#  dense_36 (Dense)               (None, 128)          16512       ['global_average_pooling2d_12[0][
#                                                                  0]']
#
#  dense_37 (Dense)               (None, 128)          16512       ['dense_36[0][0]']
#
#  dense_38 (Dense)               (None, 128, 128, 12  16512       ['batch_normalization_17[0][0]']
#                                 8)
#
#  multiply_12 (Multiply)         (None, 128, 128, 12  0           ['dense_37[0][0]',
#                                 8)                                'dense_38[0][0]']
#
#  output (Conv2D)                (None, 128, 128, 1)  129         ['multiply_12[0][0]']
#
# ==================================================================================================
# Total params: 3,208,273
# Trainable params: 3,203,665
# Non-trainable params: 4,608
# __________________________________________________________________________________________________

# %% [markdown]
# ### Defining Dice Coefficient & Loss
# Dice = 2|A∩B|/|A|+|B|

# %%
from keras.losses import binary_crossentropy
from keras import backend as K
import tensorflow as tf

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = tf.cast(K.flatten(y_true), tf.float32)
    y_pred_f = tf.cast(K.flatten(y_pred), tf.float32)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def dice_coefficient(y_true, y_pred):
    smooth = 1.
    y_true_f = tf.cast(K.flatten(y_true), tf.float32)
    y_pred_f = tf.cast(K.flatten(y_pred), tf.float32)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

### bce_dice_loss = binary_crossentropy_loss + dice_loss
def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

# %% [markdown]
# ### Defining IOU metric and compile Model

# %%
THRESHOLD = 0.5
def get_iou_vector(A, B):
    t = A>0
    p = B>0
    intersection = np.logical_and(t,p)
    union = np.logical_or(t,p)
    iou = (np.sum(intersection) + 1e-10 )/ (np.sum(union) + 1e-10)
    return iou

def iou_metric(label, pred):
    return tf.numpy_function(get_iou_vector, [label, pred>THRESHOLD], tf.float64)

model.compile(optimizer=optimizers.Adam(lr=1e-3), 
             loss=bce_dice_loss, metrics=['accuracy',iou_metric,dice_coefficient])
# Out:
# /opt/saturncloud/envs/saturn/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import LabelEncoder
from keras.models import load_model

model_checkpoint  = ModelCheckpoint('model_best_checkpoint.h5', save_best_only=True, 
                                    monitor='val_loss', mode='min', verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=5, mode='min')
reduceLR = ReduceLROnPlateau(patience=4, verbose=2, monitor='val_loss',min_lr=1e-4, mode='min')

callback_list = [early_stopping, reduceLR, model_checkpoint]

train_generator = train_datagen.flow(X, Y, batch_size=32)
val_generator = val_datagen.flow(X_v, Y_v, batch_size=32)

hist = model.fit(X,Y,batch_size=32,epochs=100,
               validation_split=0.25,verbose=1,callbacks= callback_list)
# Out:
# Epoch 1/100
# 2022-11-18 17:17:53.748379: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2022-11-18 17:17:55.765212: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-18 17:17:55.766201: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-18 17:17:55.766243: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-11-18 17:17:55.767428: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-18 17:17:55.767533: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 115/115 [==============================] - ETA: 0s - loss: 0.8238 - accuracy: 0.9552 - iou_metric: 0.2166 - dice_coefficient: 0.3162
# Epoch 1: val_loss improved from inf to 0.86678, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 87s 649ms/step - loss: 0.8238 - accuracy: 0.9552 - iou_metric: 0.2166 - dice_coefficient: 0.3162 - val_loss: 0.8668 - val_accuracy: 0.9465 - val_iou_metric: 0.2122 - val_dice_coefficient: 0.3414 - lr: 0.0010
# Epoch 2/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4988 - accuracy: 0.9803 - iou_metric: 0.4305 - dice_coefficient: 0.5792
# Epoch 2: val_loss improved from 0.86678 to 0.50605, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 69s 604ms/step - loss: 0.4988 - accuracy: 0.9803 - iou_metric: 0.4305 - dice_coefficient: 0.5792 - val_loss: 0.5060 - val_accuracy: 0.9767 - val_iou_metric: 0.4282 - val_dice_coefficient: 0.5853 - lr: 0.0010
# Epoch 3/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4161 - accuracy: 0.9835 - iou_metric: 0.5032 - dice_coefficient: 0.6510
# Epoch 3: val_loss improved from 0.50605 to 0.36189, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 613ms/step - loss: 0.4161 - accuracy: 0.9835 - iou_metric: 0.5032 - dice_coefficient: 0.6510 - val_loss: 0.3619 - val_accuracy: 0.9858 - val_iou_metric: 0.5491 - val_dice_coefficient: 0.6940 - lr: 0.0010
# Epoch 4/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3529 - accuracy: 0.9860 - iou_metric: 0.5612 - dice_coefficient: 0.7041
# Epoch 4: val_loss did not improve from 0.36189
# 115/115 [==============================] - 70s 609ms/step - loss: 0.3529 - accuracy: 0.9860 - iou_metric: 0.5612 - dice_coefficient: 0.7041 - val_loss: 0.4409 - val_accuracy: 0.9860 - val_iou_metric: 0.4719 - val_dice_coefficient: 0.6288 - lr: 0.0010
# Epoch 5/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3243 - accuracy: 0.9873 - iou_metric: 0.5915 - dice_coefficient: 0.7292
# Epoch 5: val_loss improved from 0.36189 to 0.32149, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 611ms/step - loss: 0.3243 - accuracy: 0.9873 - iou_metric: 0.5915 - dice_coefficient: 0.7292 - val_loss: 0.3215 - val_accuracy: 0.9872 - val_iou_metric: 0.5938 - val_dice_coefficient: 0.7293 - lr: 0.0010
# Epoch 6/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2937 - accuracy: 0.9884 - iou_metric: 0.6224 - dice_coefficient: 0.7543
# Epoch 6: val_loss did not improve from 0.32149
# 115/115 [==============================] - 70s 610ms/step - loss: 0.2937 - accuracy: 0.9884 - iou_metric: 0.6224 - dice_coefficient: 0.7543 - val_loss: 0.3230 - val_accuracy: 0.9887 - val_iou_metric: 0.5911 - val_dice_coefficient: 0.7337 - lr: 0.0010
# Epoch 7/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2636 - accuracy: 0.9897 - iou_metric: 0.6540 - dice_coefficient: 0.7800
# Epoch 7: val_loss improved from 0.32149 to 0.25709, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 611ms/step - loss: 0.2636 - accuracy: 0.9897 - iou_metric: 0.6540 - dice_coefficient: 0.7800 - val_loss: 0.2571 - val_accuracy: 0.9898 - val_iou_metric: 0.6610 - val_dice_coefficient: 0.7864 - lr: 0.0010
# Epoch 8/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2494 - accuracy: 0.9902 - iou_metric: 0.6699 - dice_coefficient: 0.7919
# Epoch 8: val_loss improved from 0.25709 to 0.25283, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 71s 616ms/step - loss: 0.2494 - accuracy: 0.9902 - iou_metric: 0.6699 - dice_coefficient: 0.7919 - val_loss: 0.2528 - val_accuracy: 0.9905 - val_iou_metric: 0.6658 - val_dice_coefficient: 0.7925 - lr: 0.0010
# Epoch 9/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2294 - accuracy: 0.9910 - iou_metric: 0.6927 - dice_coefficient: 0.8088
# Epoch 9: val_loss improved from 0.25283 to 0.23766, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 71s 614ms/step - loss: 0.2294 - accuracy: 0.9910 - iou_metric: 0.6927 - dice_coefficient: 0.8088 - val_loss: 0.2377 - val_accuracy: 0.9909 - val_iou_metric: 0.6817 - val_dice_coefficient: 0.8035 - lr: 0.0010
# Epoch 10/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2148 - accuracy: 0.9916 - iou_metric: 0.7092 - dice_coefficient: 0.8211
# Epoch 10: val_loss did not improve from 0.23766
# 115/115 [==============================] - 70s 609ms/step - loss: 0.2148 - accuracy: 0.9916 - iou_metric: 0.7092 - dice_coefficient: 0.8211 - val_loss: 0.2451 - val_accuracy: 0.9905 - val_iou_metric: 0.6738 - val_dice_coefficient: 0.7937 - lr: 0.0010
# Epoch 11/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2144 - accuracy: 0.9915 - iou_metric: 0.7101 - dice_coefficient: 0.8212
# Epoch 11: val_loss improved from 0.23766 to 0.22808, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 612ms/step - loss: 0.2144 - accuracy: 0.9915 - iou_metric: 0.7101 - dice_coefficient: 0.8212 - val_loss: 0.2281 - val_accuracy: 0.9912 - val_iou_metric: 0.6925 - val_dice_coefficient: 0.8098 - lr: 0.0010
# Epoch 12/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2008 - accuracy: 0.9921 - iou_metric: 0.7259 - dice_coefficient: 0.8330
# Epoch 12: val_loss did not improve from 0.22808
# 115/115 [==============================] - 70s 610ms/step - loss: 0.2008 - accuracy: 0.9921 - iou_metric: 0.7259 - dice_coefficient: 0.8330 - val_loss: 0.2281 - val_accuracy: 0.9914 - val_iou_metric: 0.6957 - val_dice_coefficient: 0.8149 - lr: 0.0010
# Epoch 13/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1925 - accuracy: 0.9924 - iou_metric: 0.7357 - dice_coefficient: 0.8397
# Epoch 13: val_loss improved from 0.22808 to 0.21456, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 612ms/step - loss: 0.1925 - accuracy: 0.9924 - iou_metric: 0.7357 - dice_coefficient: 0.8397 - val_loss: 0.2146 - val_accuracy: 0.9916 - val_iou_metric: 0.7086 - val_dice_coefficient: 0.8238 - lr: 0.0010
# Epoch 14/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1824 - accuracy: 0.9928 - iou_metric: 0.7474 - dice_coefficient: 0.8480
# Epoch 14: val_loss did not improve from 0.21456
# 115/115 [==============================] - 70s 610ms/step - loss: 0.1824 - accuracy: 0.9928 - iou_metric: 0.7474 - dice_coefficient: 0.8480 - val_loss: 0.2215 - val_accuracy: 0.9910 - val_iou_metric: 0.7039 - val_dice_coefficient: 0.8200 - lr: 0.0010
# Epoch 15/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1701 - accuracy: 0.9933 - iou_metric: 0.7625 - dice_coefficient: 0.8581
# Epoch 15: val_loss improved from 0.21456 to 0.20171, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 613ms/step - loss: 0.1701 - accuracy: 0.9933 - iou_metric: 0.7625 - dice_coefficient: 0.8581 - val_loss: 0.2017 - val_accuracy: 0.9923 - val_iou_metric: 0.7261 - val_dice_coefficient: 0.8369 - lr: 0.0010
# Epoch 16/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1635 - accuracy: 0.9936 - iou_metric: 0.7707 - dice_coefficient: 0.8638
# Epoch 16: val_loss improved from 0.20171 to 0.18982, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 613ms/step - loss: 0.1635 - accuracy: 0.9936 - iou_metric: 0.7707 - dice_coefficient: 0.8638 - val_loss: 0.1898 - val_accuracy: 0.9928 - val_iou_metric: 0.7388 - val_dice_coefficient: 0.8441 - lr: 0.0010
# Epoch 17/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1601 - accuracy: 0.9937 - iou_metric: 0.7751 - dice_coefficient: 0.8666
# Epoch 17: val_loss did not improve from 0.18982
# 115/115 [==============================] - 70s 609ms/step - loss: 0.1601 - accuracy: 0.9937 - iou_metric: 0.7751 - dice_coefficient: 0.8666 - val_loss: 0.1952 - val_accuracy: 0.9923 - val_iou_metric: 0.7307 - val_dice_coefficient: 0.8367 - lr: 0.0010
# Epoch 18/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1652 - accuracy: 0.9935 - iou_metric: 0.7692 - dice_coefficient: 0.8626
# Epoch 18: val_loss improved from 0.18982 to 0.18915, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 613ms/step - loss: 0.1652 - accuracy: 0.9935 - iou_metric: 0.7692 - dice_coefficient: 0.8626 - val_loss: 0.1891 - val_accuracy: 0.9927 - val_iou_metric: 0.7360 - val_dice_coefficient: 0.8416 - lr: 0.0010
# Epoch 19/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1529 - accuracy: 0.9940 - iou_metric: 0.7838 - dice_coefficient: 0.8725
# Epoch 19: val_loss improved from 0.18915 to 0.18604, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 613ms/step - loss: 0.1529 - accuracy: 0.9940 - iou_metric: 0.7838 - dice_coefficient: 0.8725 - val_loss: 0.1860 - val_accuracy: 0.9930 - val_iou_metric: 0.7435 - val_dice_coefficient: 0.8480 - lr: 0.0010
# Epoch 20/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1682 - accuracy: 0.9934 - iou_metric: 0.7665 - dice_coefficient: 0.8606
# Epoch 20: val_loss did not improve from 0.18604
# 115/115 [==============================] - 70s 608ms/step - loss: 0.1682 - accuracy: 0.9934 - iou_metric: 0.7665 - dice_coefficient: 0.8606 - val_loss: 0.2376 - val_accuracy: 0.9910 - val_iou_metric: 0.6879 - val_dice_coefficient: 0.8097 - lr: 0.0010
# Epoch 21/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1514 - accuracy: 0.9940 - iou_metric: 0.7859 - dice_coefficient: 0.8737
# Epoch 21: val_loss did not improve from 0.18604
# 115/115 [==============================] - 70s 608ms/step - loss: 0.1514 - accuracy: 0.9940 - iou_metric: 0.7859 - dice_coefficient: 0.8737 - val_loss: 0.1969 - val_accuracy: 0.9927 - val_iou_metric: 0.7299 - val_dice_coefficient: 0.8389 - lr: 0.0010
# Epoch 22/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1372 - accuracy: 0.9946 - iou_metric: 0.8033 - dice_coefficient: 0.8854
# Epoch 22: val_loss improved from 0.18604 to 0.17774, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 612ms/step - loss: 0.1372 - accuracy: 0.9946 - iou_metric: 0.8033 - dice_coefficient: 0.8854 - val_loss: 0.1777 - val_accuracy: 0.9932 - val_iou_metric: 0.7523 - val_dice_coefficient: 0.8533 - lr: 0.0010
# Epoch 23/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9947 - iou_metric: 0.8084 - dice_coefficient: 0.8885
# Epoch 23: val_loss improved from 0.17774 to 0.17600, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 613ms/step - loss: 0.1332 - accuracy: 0.9947 - iou_metric: 0.8084 - dice_coefficient: 0.8885 - val_loss: 0.1760 - val_accuracy: 0.9932 - val_iou_metric: 0.7557 - val_dice_coefficient: 0.8560 - lr: 0.0010
# Epoch 24/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1362 - accuracy: 0.9946 - iou_metric: 0.8050 - dice_coefficient: 0.8864
# Epoch 24: val_loss did not improve from 0.17600
# 115/115 [==============================] - 70s 608ms/step - loss: 0.1362 - accuracy: 0.9946 - iou_metric: 0.8050 - dice_coefficient: 0.8864 - val_loss: 0.1808 - val_accuracy: 0.9930 - val_iou_metric: 0.7489 - val_dice_coefficient: 0.8504 - lr: 0.0010
# Epoch 25/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1317 - accuracy: 0.9948 - iou_metric: 0.8111 - dice_coefficient: 0.8902
# Epoch 25: val_loss did not improve from 0.17600
# 115/115 [==============================] - 70s 610ms/step - loss: 0.1317 - accuracy: 0.9948 - iou_metric: 0.8111 - dice_coefficient: 0.8902 - val_loss: 0.1792 - val_accuracy: 0.9933 - val_iou_metric: 0.7517 - val_dice_coefficient: 0.8536 - lr: 0.0010
# Epoch 26/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1215 - accuracy: 0.9952 - iou_metric: 0.8242 - dice_coefficient: 0.8986
# Epoch 26: val_loss improved from 0.17600 to 0.16543, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 613ms/step - loss: 0.1215 - accuracy: 0.9952 - iou_metric: 0.8242 - dice_coefficient: 0.8986 - val_loss: 0.1654 - val_accuracy: 0.9935 - val_iou_metric: 0.7684 - val_dice_coefficient: 0.8646 - lr: 0.0010
# Epoch 27/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1275 - accuracy: 0.9949 - iou_metric: 0.8163 - dice_coefficient: 0.8934
# Epoch 27: val_loss did not improve from 0.16543
# 115/115 [==============================] - 70s 610ms/step - loss: 0.1275 - accuracy: 0.9949 - iou_metric: 0.8163 - dice_coefficient: 0.8934 - val_loss: 0.1887 - val_accuracy: 0.9924 - val_iou_metric: 0.7423 - val_dice_coefficient: 0.8467 - lr: 0.0010
# Epoch 28/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1241 - accuracy: 0.9950 - iou_metric: 0.8206 - dice_coefficient: 0.8964
# Epoch 28: val_loss did not improve from 0.16543
# 115/115 [==============================] - 70s 609ms/step - loss: 0.1241 - accuracy: 0.9950 - iou_metric: 0.8206 - dice_coefficient: 0.8964 - val_loss: 0.1711 - val_accuracy: 0.9933 - val_iou_metric: 0.7600 - val_dice_coefficient: 0.8586 - lr: 0.0010
# Epoch 29/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1181 - accuracy: 0.9953 - iou_metric: 0.8285 - dice_coefficient: 0.9013
# Epoch 29: val_loss did not improve from 0.16543
# 115/115 [==============================] - 70s 609ms/step - loss: 0.1181 - accuracy: 0.9953 - iou_metric: 0.8285 - dice_coefficient: 0.9013 - val_loss: 0.1838 - val_accuracy: 0.9930 - val_iou_metric: 0.7484 - val_dice_coefficient: 0.8523 - lr: 0.0010
# Epoch 30/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1163 - accuracy: 0.9954 - iou_metric: 0.8309 - dice_coefficient: 0.9029
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 30: val_loss did not improve from 0.16543
# 115/115 [==============================] - 70s 610ms/step - loss: 0.1163 - accuracy: 0.9954 - iou_metric: 0.8309 - dice_coefficient: 0.9029 - val_loss: 0.1756 - val_accuracy: 0.9934 - val_iou_metric: 0.7538 - val_dice_coefficient: 0.8551 - lr: 0.0010
# Epoch 31/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1034 - accuracy: 0.9959 - iou_metric: 0.8477 - dice_coefficient: 0.9130
# Epoch 31: val_loss improved from 0.16543 to 0.15409, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 612ms/step - loss: 0.1034 - accuracy: 0.9959 - iou_metric: 0.8477 - dice_coefficient: 0.9130 - val_loss: 0.1541 - val_accuracy: 0.9941 - val_iou_metric: 0.7809 - val_dice_coefficient: 0.8728 - lr: 1.0000e-04
# Epoch 32/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0966 - accuracy: 0.9961 - iou_metric: 0.8567 - dice_coefficient: 0.9187
# Epoch 32: val_loss improved from 0.15409 to 0.14975, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 613ms/step - loss: 0.0966 - accuracy: 0.9961 - iou_metric: 0.8567 - dice_coefficient: 0.9187 - val_loss: 0.1498 - val_accuracy: 0.9942 - val_iou_metric: 0.7871 - val_dice_coefficient: 0.8769 - lr: 1.0000e-04
# Epoch 33/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0941 - accuracy: 0.9962 - iou_metric: 0.8602 - dice_coefficient: 0.9208
# Epoch 33: val_loss did not improve from 0.14975
# 115/115 [==============================] - 70s 610ms/step - loss: 0.0941 - accuracy: 0.9962 - iou_metric: 0.8602 - dice_coefficient: 0.9208 - val_loss: 0.1514 - val_accuracy: 0.9942 - val_iou_metric: 0.7854 - val_dice_coefficient: 0.8761 - lr: 1.0000e-04
# Epoch 34/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0919 - accuracy: 0.9963 - iou_metric: 0.8634 - dice_coefficient: 0.9227
# Epoch 34: val_loss improved from 0.14975 to 0.14939, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 613ms/step - loss: 0.0919 - accuracy: 0.9963 - iou_metric: 0.8634 - dice_coefficient: 0.9227 - val_loss: 0.1494 - val_accuracy: 0.9943 - val_iou_metric: 0.7878 - val_dice_coefficient: 0.8774 - lr: 1.0000e-04
# Epoch 35/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9963 - iou_metric: 0.8636 - dice_coefficient: 0.9229
# Epoch 35: val_loss did not improve from 0.14939
# 115/115 [==============================] - 70s 608ms/step - loss: 0.0916 - accuracy: 0.9963 - iou_metric: 0.8636 - dice_coefficient: 0.9229 - val_loss: 0.1495 - val_accuracy: 0.9943 - val_iou_metric: 0.7880 - val_dice_coefficient: 0.8776 - lr: 1.0000e-04
# Epoch 36/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0904 - accuracy: 0.9964 - iou_metric: 0.8656 - dice_coefficient: 0.9240
# Epoch 36: val_loss improved from 0.14939 to 0.14759, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 71s 614ms/step - loss: 0.0904 - accuracy: 0.9964 - iou_metric: 0.8656 - dice_coefficient: 0.9240 - val_loss: 0.1476 - val_accuracy: 0.9943 - val_iou_metric: 0.7906 - val_dice_coefficient: 0.8789 - lr: 1.0000e-04
# Epoch 37/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0887 - accuracy: 0.9964 - iou_metric: 0.8678 - dice_coefficient: 0.9253
# Epoch 37: val_loss did not improve from 0.14759
# 115/115 [==============================] - 70s 609ms/step - loss: 0.0887 - accuracy: 0.9964 - iou_metric: 0.8678 - dice_coefficient: 0.9253 - val_loss: 0.1491 - val_accuracy: 0.9943 - val_iou_metric: 0.7896 - val_dice_coefficient: 0.8787 - lr: 1.0000e-04
# Epoch 38/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0878 - accuracy: 0.9965 - iou_metric: 0.8691 - dice_coefficient: 0.9262
# Epoch 38: val_loss did not improve from 0.14759
# 115/115 [==============================] - 70s 608ms/step - loss: 0.0878 - accuracy: 0.9965 - iou_metric: 0.8691 - dice_coefficient: 0.9262 - val_loss: 0.1489 - val_accuracy: 0.9943 - val_iou_metric: 0.7894 - val_dice_coefficient: 0.8788 - lr: 1.0000e-04
# Epoch 39/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.9966 - iou_metric: 0.8712 - dice_coefficient: 0.9274
# Epoch 39: val_loss did not improve from 0.14759
# 115/115 [==============================] - 68s 593ms/step - loss: 0.0863 - accuracy: 0.9966 - iou_metric: 0.8712 - dice_coefficient: 0.9274 - val_loss: 0.1486 - val_accuracy: 0.9943 - val_iou_metric: 0.7898 - val_dice_coefficient: 0.8788 - lr: 1.0000e-04
# Epoch 40/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9966 - iou_metric: 0.8730 - dice_coefficient: 0.9284
# Epoch 40: val_loss improved from 0.14759 to 0.14660, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 68s 596ms/step - loss: 0.0851 - accuracy: 0.9966 - iou_metric: 0.8730 - dice_coefficient: 0.9284 - val_loss: 0.1466 - val_accuracy: 0.9944 - val_iou_metric: 0.7928 - val_dice_coefficient: 0.8811 - lr: 1.0000e-04
# Epoch 41/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9966 - iou_metric: 0.8747 - dice_coefficient: 0.9295
# Epoch 41: val_loss did not improve from 0.14660
# 115/115 [==============================] - 68s 592ms/step - loss: 0.0839 - accuracy: 0.9966 - iou_metric: 0.8747 - dice_coefficient: 0.9295 - val_loss: 0.1484 - val_accuracy: 0.9944 - val_iou_metric: 0.7901 - val_dice_coefficient: 0.8793 - lr: 1.0000e-04
# Epoch 42/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0837 - accuracy: 0.9966 - iou_metric: 0.8750 - dice_coefficient: 0.9296
# Epoch 42: val_loss improved from 0.14660 to 0.14608, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 69s 599ms/step - loss: 0.0837 - accuracy: 0.9966 - iou_metric: 0.8750 - dice_coefficient: 0.9296 - val_loss: 0.1461 - val_accuracy: 0.9944 - val_iou_metric: 0.7938 - val_dice_coefficient: 0.8815 - lr: 1.0000e-04
# Epoch 43/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9967 - iou_metric: 0.8772 - dice_coefficient: 0.9310
# Epoch 43: val_loss improved from 0.14608 to 0.14553, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 607ms/step - loss: 0.0820 - accuracy: 0.9967 - iou_metric: 0.8772 - dice_coefficient: 0.9310 - val_loss: 0.1455 - val_accuracy: 0.9944 - val_iou_metric: 0.7949 - val_dice_coefficient: 0.8824 - lr: 1.0000e-04
# Epoch 44/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9967 - iou_metric: 0.8774 - dice_coefficient: 0.9310
# Epoch 44: val_loss improved from 0.14553 to 0.14543, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 70s 613ms/step - loss: 0.0820 - accuracy: 0.9967 - iou_metric: 0.8774 - dice_coefficient: 0.9310 - val_loss: 0.1454 - val_accuracy: 0.9944 - val_iou_metric: 0.7942 - val_dice_coefficient: 0.8819 - lr: 1.0000e-04
# Epoch 45/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9967 - iou_metric: 0.8778 - dice_coefficient: 0.9314
# Epoch 45: val_loss did not improve from 0.14543
# 115/115 [==============================] - 70s 611ms/step - loss: 0.0815 - accuracy: 0.9967 - iou_metric: 0.8778 - dice_coefficient: 0.9314 - val_loss: 0.1468 - val_accuracy: 0.9944 - val_iou_metric: 0.7935 - val_dice_coefficient: 0.8816 - lr: 1.0000e-04
# Epoch 46/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0803 - accuracy: 0.9968 - iou_metric: 0.8798 - dice_coefficient: 0.9325
# Epoch 46: val_loss did not improve from 0.14543
# 115/115 [==============================] - 70s 612ms/step - loss: 0.0803 - accuracy: 0.9968 - iou_metric: 0.8798 - dice_coefficient: 0.9325 - val_loss: 0.1483 - val_accuracy: 0.9944 - val_iou_metric: 0.7916 - val_dice_coefficient: 0.8805 - lr: 1.0000e-04
# Epoch 47/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0800 - accuracy: 0.9968 - iou_metric: 0.8803 - dice_coefficient: 0.9328
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 47: val_loss did not improve from 0.14543
# 115/115 [==============================] - 70s 609ms/step - loss: 0.0800 - accuracy: 0.9968 - iou_metric: 0.8803 - dice_coefficient: 0.9328 - val_loss: 0.1487 - val_accuracy: 0.9944 - val_iou_metric: 0.7915 - val_dice_coefficient: 0.8802 - lr: 1.0000e-04
# Epoch 48/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0787 - accuracy: 0.9968 - iou_metric: 0.8820 - dice_coefficient: 0.9338
# Epoch 48: val_loss improved from 0.14543 to 0.14474, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 69s 599ms/step - loss: 0.0787 - accuracy: 0.9968 - iou_metric: 0.8820 - dice_coefficient: 0.9338 - val_loss: 0.1447 - val_accuracy: 0.9944 - val_iou_metric: 0.7954 - val_dice_coefficient: 0.8827 - lr: 1.0000e-04
# Epoch 49/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0783 - accuracy: 0.9969 - iou_metric: 0.8826 - dice_coefficient: 0.9342
# Epoch 49: val_loss did not improve from 0.14474
# 115/115 [==============================] - 68s 592ms/step - loss: 0.0783 - accuracy: 0.9969 - iou_metric: 0.8826 - dice_coefficient: 0.9342 - val_loss: 0.1451 - val_accuracy: 0.9945 - val_iou_metric: 0.7965 - val_dice_coefficient: 0.8836 - lr: 1.0000e-04
# Epoch 50/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0784 - accuracy: 0.9969 - iou_metric: 0.8824 - dice_coefficient: 0.9341
# Epoch 50: val_loss did not improve from 0.14474
# 115/115 [==============================] - 68s 593ms/step - loss: 0.0784 - accuracy: 0.9969 - iou_metric: 0.8824 - dice_coefficient: 0.9341 - val_loss: 0.1459 - val_accuracy: 0.9945 - val_iou_metric: 0.7946 - val_dice_coefficient: 0.8825 - lr: 1.0000e-04
# Epoch 51/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0774 - accuracy: 0.9969 - iou_metric: 0.8838 - dice_coefficient: 0.9348
# Epoch 51: val_loss did not improve from 0.14474
# 115/115 [==============================] - 69s 597ms/step - loss: 0.0774 - accuracy: 0.9969 - iou_metric: 0.8838 - dice_coefficient: 0.9348 - val_loss: 0.1477 - val_accuracy: 0.9944 - val_iou_metric: 0.7931 - val_dice_coefficient: 0.8815 - lr: 1.0000e-04
# Epoch 52/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9969 - iou_metric: 0.8845 - dice_coefficient: 0.9353
# Epoch 52: val_loss did not improve from 0.14474
# 115/115 [==============================] - 69s 605ms/step - loss: 0.0768 - accuracy: 0.9969 - iou_metric: 0.8845 - dice_coefficient: 0.9353 - val_loss: 0.1470 - val_accuracy: 0.9944 - val_iou_metric: 0.7936 - val_dice_coefficient: 0.8818 - lr: 1.0000e-04
# Epoch 53/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0762 - accuracy: 0.9969 - iou_metric: 0.8855 - dice_coefficient: 0.9358
# Epoch 53: val_loss did not improve from 0.14474
# 115/115 [==============================] - 70s 612ms/step - loss: 0.0762 - accuracy: 0.9969 - iou_metric: 0.8855 - dice_coefficient: 0.9358 - val_loss: 0.1468 - val_accuracy: 0.9944 - val_iou_metric: 0.7945 - val_dice_coefficient: 0.8822 - lr: 1.0000e-04

# %%
model = load_model('model_best_checkpoint.h5', custom_objects={'bce_dice_loss': bce_dice_loss,'iou_metric':iou_metric,'dice_coefficient':dice_coefficient}) #or compile = False

# %% [markdown]
# ### Plot graph of Dice Loss, IoU Metric, and Dice Coefficient

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 4))
t = f.suptitle('Model Performance in Segmenting Tumors', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)
epoch_list = hist.epoch

ax1.plot(epoch_list, hist.history['loss'], label='Train Dice Loss')
ax1.plot(epoch_list, hist.history['val_loss'], label='Val Dice Loss')
ax1.set_xticks(np.arange(0, epoch_list[-1], 5))
ax1.set_ylabel('Dice Loss Value');ax1.set_xlabel('Epoch');ax1.set_title('Dice Loss')
ax1.legend(loc="best");ax1.grid(color='gray', linestyle='-', linewidth=0.5)

ax2.plot(epoch_list, hist.history['dice_coefficient'], label='Train Dice Coeff')
ax2.plot(epoch_list, hist.history['val_dice_coefficient'], label='Val Dice Coeff')
ax2.set_xticks(np.arange(0, epoch_list[-1], 5))
ax2.set_ylabel('Dice Coefficient Value');ax2.set_xlabel('Epoch');ax2.set_title('Dice Coefficient')
ax2.legend(loc="best");ax2.grid(color='gray', linestyle='-', linewidth=0.5)

ax3.plot(epoch_list, hist.history['iou_metric'], label='Train IOU metric')
ax3.plot(epoch_list, hist.history['val_iou_metric'], label='Val IOU metric')
ax3.set_xticks(np.arange(0, epoch_list[-1], 5))
ax3.set_ylabel('IOU metric');ax3.set_xlabel('Epoch');ax3.set_title('IOU metric')
ax3.legend(loc="best");ax3.grid(color='gray', linestyle='-', linewidth=0.5)

# %% [markdown]
# ### Plot IoU Curve using different Thresholds

# %%
def getIOUCurve(mask_org,predicted):
  thresholds = np.linspace(0, 1, 100)
  ious = np.array([get_iou_vector(mask_org, predicted > threshold) for threshold in thresholds])
  thres_best_index = np.argmax(ious[9:-10]) + 9
  iou_best = ious[thres_best_index]
  thres_best = thresholds[thres_best_index]
  return thresholds,ious,iou_best,thres_best

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Model Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

th, ious, iou_best, th_best = getIOUCurve(Y_v,model.predict(X_v))
ax1.plot(th, ious,label="For Validation")
ax1.plot(th_best, iou_best, "xr", label="Best threshold")
ax1.set_ylabel('IOU');ax1.set_xlabel('Threshold')
ax1.set_title("Threshold vs IoU ({}, {})".format(round(th_best, 4), round(iou_best, 4)))

th, ious, iou_best, th_best = getIOUCurve(Y,model.predict(X))
ax2.plot(th, ious, label="For Training")
ax2.plot(th_best, iou_best, "xr", label="Best threshold")
ax2.set_ylabel('IOU');ax2.set_xlabel('Threshold')
ax2.set_title("Threshold vs IoU ({}, {})".format(round(th_best, 4), round(iou_best, 4)))
# Out:
# 20/20 [==============================] - 4s 180ms/step
# 154/154 [==============================] - 25s 162ms/step
# Text(0.5, 1.0, 'Threshold vs IoU (0.6263, 0.8696)')

# %% [markdown]
# ### Determine IoU and Dice Coefficient for Threshold=0.5

# %%
pred_mask = model.predict(X_v)
iou_score = iou_metric(Y_v, pred_mask)
dice_coeff = dice_coefficient(Y_v, pred_mask)
print("IoU score is: ", tf.get_static_value(iou_score))
print("Dice Coefficient is: ", tf.get_static_value(dice_coeff))
# Out:
# 20/20 [==============================] - 3s 151ms/step
# IoU score is:  0.7709932745939212
# Dice Coefficient is:  0.86818415

# %% [markdown]
# ### Predict Masks

# %%
predicted_mask = pred_mask>THRESHOLD

plt.figure(figsize=(8,30))
i=1;total=10
temp = np.ones_like( Y_v[0] )
for idx in np.random.randint(0,high=X_v.shape[0],size=total):
    plt.subplot(total,3,i);i+=1
    plt.imshow( np.squeeze(X_v[idx],axis=-1), cmap='gray' )
    plt.title("MRI Image");plt.axis('off')
    
    plt.subplot(total,3,i);i+=1
    plt.imshow( np.squeeze(X_v[idx],axis=-1), cmap='gray' )
    plt.imshow( np.squeeze(temp - Y_v[idx],axis=-1), alpha=0.2, cmap='Set1' )
    plt.title("Original Mask");plt.axis('off')
    
    plt.subplot(total,3,i);i+=1
    plt.imshow( np.squeeze(X_v[idx],axis=-1), cmap='gray' )
    plt.imshow( np.squeeze(temp - predicted_mask[idx],axis=-1),  alpha=0.2, cmap='Set1' )
    plt.title("Predicted Mask");plt.axis('off')
