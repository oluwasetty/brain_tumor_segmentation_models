# %%
# !pip install hdf5storage
# !git clone https://github.com/adityajn105/brain-tumor-segmentation-unet
# !bash tumor-segmentation-unet/download_data.sh
# !python mat_to_numpy.py brain_tumor_dataset/
# !pip install scikit-image
# !pip install scikit-learn
# Out:
# Collecting scikit-image
#   Using cached scikit_image-0.19.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
# Collecting networkx>=2.2
#   Using cached networkx-2.8.8-py3-none-any.whl (2.0 MB)
# Collecting PyWavelets>=1.1.1
#   Using cached PyWavelets-1.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
# Collecting imageio>=2.4.1
#   Using cached imageio-2.22.4-py3-none-any.whl (3.4 MB)
# Collecting scipy>=1.4.1
#   Using cached scipy-1.9.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
# Requirement already satisfied: packaging>=20.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-image) (21.3)
# Requirement already satisfied: numpy>=1.17.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-image) (1.21.6)
# Collecting tifffile>=2019.7.26
#   Using cached tifffile-2022.10.10-py3-none-any.whl (210 kB)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-image) (9.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from packaging>=20.0->scikit-image) (3.0.9)
# Installing collected packages: tifffile, scipy, PyWavelets, networkx, imageio, scikit-image
# Successfully installed PyWavelets-1.4.1 imageio-2.22.4 networkx-2.8.8 scikit-image-0.19.3 scipy-1.9.3 tifffile-2022.10.10
# Collecting scikit-learn
#   Using cached scikit_learn-1.1.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.8 MB)
# Requirement already satisfied: scipy>=1.3.2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-learn) (1.9.3)
# Collecting joblib>=1.0.0
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.17.3 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-learn) (1.21.6)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.1.3 threadpoolctl-3.1.0

# %%
# import zipfile as zf

# files = zf.ZipFile("dataset.zip",'r')
# files.extractall()
# files.close()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

integer_to_class = {'1': 'meningioma (1)', '2': 'glioma (2)', '3': 'pituitary tumor (3)'}

##Load images, labels, masks
labels = np.load('dataset/labels.npy')
images = np.clip( (np.load('dataset/images.npy')/12728),0,1)
masks = np.load('dataset/masks.npy')*1
print(labels.shape)
print(images.shape)
print(masks.shape)
# Out:
# (3064,)
# (3064, 512, 512)
# (3064, 512, 512)

# %%
from skimage.transform import resize
img_size_ori = 512
img_size_target = 128

images = np.expand_dims(images,axis=-1)
masks = np.expand_dims(masks,axis=-1)

def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True,)
    
def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)
  
images = np.array([ downsample(image) for image in images ])
masks = (np.array([ downsample(mask) for mask in masks ])>0)*1

print(images.shape)
print(masks.shape)
# Out:
# (3064, 128, 128, 1)
# (3064, 128, 128, 1)

# %%
classes, counts = np.unique(labels,return_counts=True)
plt.bar(classes,counts,tick_label=list(integer_to_class.values()))
print(counts)
# Out:
# [ 708 1426  930]

# %%
plt.figure(figsize=(12, 5))
for i, idx in enumerate(np.random.randint(images.shape[0], size=18), start=1):
    plt.subplot(3, 6, i)
    plt.imshow( np.squeeze(images[idx],axis=-1), cmap='gray')
    plt.imshow( np.squeeze(np.ones_like(masks[idx])-masks[idx],axis=-1), alpha=0.5, cmap='Set1')
    plt.title(integer_to_class[str(labels[idx])])
    plt.axis('off')

# %% [markdown]
# ### Train Image and its mask which is to be predicted

# %%
plt.figure(figsize=(12, 5))
i=1
for idx in np.random.randint( images.shape[0], size=9):
  plt.subplot(3,6,i);i+=1
  plt.imshow( np.squeeze(images[idx],axis=-1))
  plt.title("Train Image")
  plt.axis('off')
  plt.subplot(3,6,i);i+=1
  plt.imshow( np.squeeze(masks[idx],axis=-1)) 
  plt.title("Train Mask")
  plt.axis('off')

# %%
from sklearn.model_selection import train_test_split
import gc
X,X_v,Y,Y_v = train_test_split( images,masks,test_size=0.2,stratify=labels)
del images
del masks
del labels
gc.collect()
X.shape,X_v.shape
# Out:
# ((2451, 128, 128, 1), (613, 128, 128, 1))

# %% [markdown]
# ### Augmentation

# %%
X = np.append( X, [ np.fliplr(x) for x in X], axis=0 )
Y = np.append( Y, [ np.fliplr(y) for y in Y], axis=0 )
X.shape,Y.shape
# Out:
# ((4902, 128, 128, 1), (4902, 128, 128, 1))

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(brightness_range=(0.9,1.1),
                                   zoom_range=[.9,1.1],
                                   fill_mode='nearest')
val_datagen = ImageDataGenerator()
# Out:
# 2022-11-18 14:23:57.487997: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# ### Defining the Model

# %%
from keras.layers import Conv2D, MaxPooling2D, Conv2DTranspose, concatenate, Dropout, Input, BatchNormalization
from keras import optimizers
from keras.models import Model

IMG_DIM = (128,128,1)

def conv2d_block( input_tensor, n_filters, kernel_size = (3,3), name="contraction"):
    
    "Add 2 conv layer"
    x = Conv2D(filters=n_filters, kernel_size=kernel_size, kernel_initializer='he_normal', 
             padding='same',activation="relu", name=name+'_1')(input_tensor)
    
    x = Dropout(0.1)(x)
  
    x = Conv2D(filters=n_filters, kernel_size=kernel_size, kernel_initializer='he_normal', 
             padding='same',activation="relu",name=name+'_2')(x)
    return x
  

inp = Input( shape=IMG_DIM )

d1 = conv2d_block( inp, 64, name="contraction_1")
p1 = MaxPooling2D( pool_size=(2,2), strides=(2,2))(d1)
p1 = BatchNormalization(momentum=0.8)(p1)

d2 = conv2d_block( p1, 128, name="contraction_2_1" )
p2 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d2)
p2 = BatchNormalization(momentum=0.8)(p2)

d3 = conv2d_block( p2, 256, name="contraction_3_1")
p3 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d3)
p3 = BatchNormalization(momentum=0.8)(p3)

d4 = conv2d_block(p3,512, name="contraction_4_1")
p4 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d4)
p4 = BatchNormalization(momentum=0.8)(p4)

d5 = conv2d_block(p4,1024, name="contraction_5_1")

u1 = Conv2DTranspose(512, (3, 3), strides = (2, 2), padding = 'same')(d5)
u1 = concatenate([u1,d4])
c1 = conv2d_block(u1, 512, name="expansion_1")

u2 = Conv2DTranspose(256, (3, 3), strides = (2, 2), padding = 'same')(c1)
u2 = concatenate([u2,d3])
c2 = conv2d_block(u2, 256, name="expansion_2")

u3 = Conv2DTranspose(128, (3, 3), strides = (2, 2), padding = 'same')(c2)
u3 = concatenate([u3,d2])
c3 = conv2d_block(u3, 128, name="expansion_3")

u4 = Conv2DTranspose(64, (3, 3), strides = (2, 2), padding = 'same')(c3)
u4 = concatenate([u4,d1])
c4 = conv2d_block(u4,64, name="expansion_4")

out = Conv2D(1, (1,1), name="output", activation='sigmoid')(c4)

model = Model( inp, out )
model.summary()
# Out:
# 2022-11-18 14:24:05.438209: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 14:24:05.515815: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 14:24:05.516490: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 14:24:05.518054: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-18 14:24:05.520343: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 14:24:05.521042: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 14:24:05.521693: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 14:24:07.028613: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 14:24:07.029295: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 14:24:07.029903: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 14:24:07.030452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13795 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  contraction_1_1 (Conv2D)       (None, 128, 128, 64  640         ['input_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 128, 128, 64  0           ['contraction_1_1[0][0]']
#                                 )
#
#  contraction_1_2 (Conv2D)       (None, 128, 128, 64  36928       ['dropout[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 64)   0           ['contraction_1_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64, 64, 64)  256         ['max_pooling2d[0][0]']
#  alization)
#
#  contraction_2_1_1 (Conv2D)     (None, 64, 64, 128)  73856       ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 64, 128)  0           ['contraction_2_1_1[0][0]']
#
#  contraction_2_1_2 (Conv2D)     (None, 64, 64, 128)  147584      ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0          ['contraction_2_1_2[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 128)  512        ['max_pooling2d_1[0][0]']
#  rmalization)
#
#  contraction_3_1_1 (Conv2D)     (None, 32, 32, 256)  295168      ['batch_normalization_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 32, 32, 256)  0           ['contraction_3_1_1[0][0]']
#
#  contraction_3_1_2 (Conv2D)     (None, 32, 32, 256)  590080      ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0          ['contraction_3_1_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 256)  1024       ['max_pooling2d_2[0][0]']
#  rmalization)
#
#  contraction_4_1_1 (Conv2D)     (None, 16, 16, 512)  1180160     ['batch_normalization_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 16, 16, 512)  0           ['contraction_4_1_1[0][0]']
#
#  contraction_4_1_2 (Conv2D)     (None, 16, 16, 512)  2359808     ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 512)   0           ['contraction_4_1_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 8, 8, 512)   2048        ['max_pooling2d_3[0][0]']
#  rmalization)
#
#  contraction_5_1_1 (Conv2D)     (None, 8, 8, 1024)   4719616     ['batch_normalization_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 8, 8, 1024)   0           ['contraction_5_1_1[0][0]']
#
#  contraction_5_1_2 (Conv2D)     (None, 8, 8, 1024)   9438208     ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 512)  4719104    ['contraction_5_1_2[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'contraction_4_1_2[0][0]']
#
#  expansion_1_1 (Conv2D)         (None, 16, 16, 512)  4719104     ['concatenate[0][0]']
#
#  dropout_5 (Dropout)            (None, 16, 16, 512)  0           ['expansion_1_1[0][0]']
#
#  expansion_1_2 (Conv2D)         (None, 16, 16, 512)  2359808     ['dropout_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 256)  1179904    ['expansion_1_2[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'contraction_3_1_2[0][0]']
#
#  expansion_2_1 (Conv2D)         (None, 32, 32, 256)  1179904     ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)            (None, 32, 32, 256)  0           ['expansion_2_1[0][0]']
#
#  expansion_2_2 (Conv2D)         (None, 32, 32, 256)  590080      ['dropout_6[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 128)  295040     ['expansion_2_2[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'contraction_2_1_2[0][0]']
#
#  expansion_3_1 (Conv2D)         (None, 64, 64, 128)  295040      ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)            (None, 64, 64, 128)  0           ['expansion_3_1[0][0]']
#
#  expansion_3_2 (Conv2D)         (None, 64, 64, 128)  147584      ['dropout_7[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  73792      ['expansion_3_2[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'contraction_1_2[0][0]']
#
#  expansion_4_1 (Conv2D)         (None, 128, 128, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 128, 128, 64  0           ['expansion_4_1[0][0]']
#                                 )
#
#  expansion_4_2 (Conv2D)         (None, 128, 128, 64  36928       ['dropout_8[0][0]']
#                                 )
#
#  output (Conv2D)                (None, 128, 128, 1)  65          ['expansion_4_2[0][0]']
#
# ==================================================================================================
# Total params: 34,516,033
# Trainable params: 34,514,113
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %% [markdown]
# ### Defining Dice Coefficient & Loss
# Dice = 2|A∩B|/|A|+|B|

# %%
from keras.losses import binary_crossentropy
from keras import backend as K
import tensorflow as tf

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = tf.cast(K.flatten(y_true), tf.float32)
    y_pred_f = tf.cast(K.flatten(y_pred), tf.float32)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def dice_coefficient(y_true, y_pred):
    smooth = 1.
    y_true_f = tf.cast(K.flatten(y_true), tf.float32)
    y_pred_f = tf.cast(K.flatten(y_pred), tf.float32)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

### bce_dice_loss = binary_crossentropy_loss + dice_loss
def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

# %% [markdown]
# ### Defining IOU metric and compile Model

# %%
THRESHOLD = 0.5
def get_iou_vector(A, B):
    t = A>0
    p = B>0
    intersection = np.logical_and(t,p)
    union = np.logical_or(t,p)
    iou = (np.sum(intersection) + 1e-10 )/ (np.sum(union) + 1e-10)
    return iou

def iou_metric(label, pred):
    return tf.numpy_function(get_iou_vector, [label, pred>THRESHOLD], tf.float64)

model.compile(optimizer=optimizers.Adam(lr=1e-3), 
             loss=bce_dice_loss, metrics=['accuracy',iou_metric,dice_coefficient])
# Out:
# /opt/saturncloud/envs/saturn/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import LabelEncoder
from keras.models import load_model

model_checkpoint  = ModelCheckpoint('model_best_checkpoint.h5', save_best_only=True, 
                                    monitor='val_loss', mode='min', verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=5, mode='min')
reduceLR = ReduceLROnPlateau(patience=4, verbose=2, monitor='val_loss',min_lr=1e-4, mode='min')

callback_list = [early_stopping, reduceLR, model_checkpoint]

train_generator = train_datagen.flow(X, Y, batch_size=32)
val_generator = val_datagen.flow(X_v, Y_v, batch_size=32)

hist = model.fit(X,Y,batch_size=32,epochs=100,
               validation_split=0.25,verbose=1,callbacks= callback_list)
# Out:
# Epoch 1/100
# 2022-11-18 14:24:12.280317: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2022-11-18 14:24:14.290470: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-18 14:24:14.291547: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-18 14:24:14.291587: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-11-18 14:24:14.292726: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-18 14:24:14.292840: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 115/115 [==============================] - ETA: 0s - loss: 1.1070 - accuracy: 0.9431 - iou_metric: 0.0872 - dice_coefficient: 0.1622
# Epoch 1: val_loss improved from inf to 0.96733, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 82s 585ms/step - loss: 1.1070 - accuracy: 0.9431 - iou_metric: 0.0872 - dice_coefficient: 0.1622 - val_loss: 0.9673 - val_accuracy: 0.9712 - val_iou_metric: 0.0802 - val_dice_coefficient: 0.1587 - lr: 0.0010
# Epoch 2/100
# 115/115 [==============================] - ETA: 0s - loss: 0.7850 - accuracy: 0.9638 - iou_metric: 0.2215 - dice_coefficient: 0.3248
# Epoch 2: val_loss improved from 0.96733 to 0.64208, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 58s 506ms/step - loss: 0.7850 - accuracy: 0.9638 - iou_metric: 0.2215 - dice_coefficient: 0.3248 - val_loss: 0.6421 - val_accuracy: 0.9733 - val_iou_metric: 0.3214 - val_dice_coefficient: 0.4632 - lr: 0.0010
# Epoch 3/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5135 - accuracy: 0.9800 - iou_metric: 0.4213 - dice_coefficient: 0.5679
# Epoch 3: val_loss improved from 0.64208 to 0.53565, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 58s 502ms/step - loss: 0.5135 - accuracy: 0.9800 - iou_metric: 0.4213 - dice_coefficient: 0.5679 - val_loss: 0.5356 - val_accuracy: 0.9750 - val_iou_metric: 0.4120 - val_dice_coefficient: 0.5649 - lr: 0.0010
# Epoch 4/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4119 - accuracy: 0.9840 - iou_metric: 0.5084 - dice_coefficient: 0.6549
# Epoch 4: val_loss improved from 0.53565 to 0.39458, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 58s 503ms/step - loss: 0.4119 - accuracy: 0.9840 - iou_metric: 0.5084 - dice_coefficient: 0.6549 - val_loss: 0.3946 - val_accuracy: 0.9846 - val_iou_metric: 0.5215 - val_dice_coefficient: 0.6684 - lr: 0.0010
# Epoch 5/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3625 - accuracy: 0.9861 - iou_metric: 0.5555 - dice_coefficient: 0.6973
# Epoch 5: val_loss did not improve from 0.39458
# 115/115 [==============================] - 55s 481ms/step - loss: 0.3625 - accuracy: 0.9861 - iou_metric: 0.5555 - dice_coefficient: 0.6973 - val_loss: 0.4066 - val_accuracy: 0.9829 - val_iou_metric: 0.5215 - val_dice_coefficient: 0.6675 - lr: 0.0010
# Epoch 6/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3246 - accuracy: 0.9875 - iou_metric: 0.5922 - dice_coefficient: 0.7290
# Epoch 6: val_loss did not improve from 0.39458
# 115/115 [==============================] - 56s 485ms/step - loss: 0.3246 - accuracy: 0.9875 - iou_metric: 0.5922 - dice_coefficient: 0.7290 - val_loss: 0.4393 - val_accuracy: 0.9834 - val_iou_metric: 0.4799 - val_dice_coefficient: 0.6378 - lr: 0.0010
# Epoch 7/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2966 - accuracy: 0.9885 - iou_metric: 0.6192 - dice_coefficient: 0.7519
# Epoch 7: val_loss improved from 0.39458 to 0.34591, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 59s 517ms/step - loss: 0.2966 - accuracy: 0.9885 - iou_metric: 0.6192 - dice_coefficient: 0.7519 - val_loss: 0.3459 - val_accuracy: 0.9873 - val_iou_metric: 0.5782 - val_dice_coefficient: 0.7257 - lr: 0.0010
# Epoch 8/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2744 - accuracy: 0.9893 - iou_metric: 0.6437 - dice_coefficient: 0.7710
# Epoch 8: val_loss improved from 0.34591 to 0.29833, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 61s 530ms/step - loss: 0.2744 - accuracy: 0.9893 - iou_metric: 0.6437 - dice_coefficient: 0.7710 - val_loss: 0.2983 - val_accuracy: 0.9887 - val_iou_metric: 0.6157 - val_dice_coefficient: 0.7519 - lr: 0.0010
# Epoch 9/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2606 - accuracy: 0.9899 - iou_metric: 0.6584 - dice_coefficient: 0.7825
# Epoch 9: val_loss did not improve from 0.29833
# 115/115 [==============================] - 59s 516ms/step - loss: 0.2606 - accuracy: 0.9899 - iou_metric: 0.6584 - dice_coefficient: 0.7825 - val_loss: 0.3075 - val_accuracy: 0.9886 - val_iou_metric: 0.6100 - val_dice_coefficient: 0.7508 - lr: 0.0010
# Epoch 10/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2441 - accuracy: 0.9905 - iou_metric: 0.6770 - dice_coefficient: 0.7967
# Epoch 10: val_loss improved from 0.29833 to 0.29614, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 62s 542ms/step - loss: 0.2441 - accuracy: 0.9905 - iou_metric: 0.6770 - dice_coefficient: 0.7967 - val_loss: 0.2961 - val_accuracy: 0.9885 - val_iou_metric: 0.6203 - val_dice_coefficient: 0.7585 - lr: 0.0010
# Epoch 11/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2360 - accuracy: 0.9908 - iou_metric: 0.6860 - dice_coefficient: 0.8031
# Epoch 11: val_loss improved from 0.29614 to 0.27354, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 62s 543ms/step - loss: 0.2360 - accuracy: 0.9908 - iou_metric: 0.6860 - dice_coefficient: 0.8031 - val_loss: 0.2735 - val_accuracy: 0.9897 - val_iou_metric: 0.6483 - val_dice_coefficient: 0.7804 - lr: 0.0010
# Epoch 12/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2153 - accuracy: 0.9917 - iou_metric: 0.7094 - dice_coefficient: 0.8206
# Epoch 12: val_loss improved from 0.27354 to 0.27232, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 62s 541ms/step - loss: 0.2153 - accuracy: 0.9917 - iou_metric: 0.7094 - dice_coefficient: 0.8206 - val_loss: 0.2723 - val_accuracy: 0.9892 - val_iou_metric: 0.6513 - val_dice_coefficient: 0.7761 - lr: 0.0010
# Epoch 13/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2034 - accuracy: 0.9920 - iou_metric: 0.7233 - dice_coefficient: 0.8304
# Epoch 13: val_loss improved from 0.27232 to 0.25813, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 59s 511ms/step - loss: 0.2034 - accuracy: 0.9920 - iou_metric: 0.7233 - dice_coefficient: 0.8304 - val_loss: 0.2581 - val_accuracy: 0.9901 - val_iou_metric: 0.6589 - val_dice_coefficient: 0.7851 - lr: 0.0010
# Epoch 14/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2222 - accuracy: 0.9914 - iou_metric: 0.7014 - dice_coefficient: 0.8147
# Epoch 14: val_loss did not improve from 0.25813
# 115/115 [==============================] - 55s 480ms/step - loss: 0.2222 - accuracy: 0.9914 - iou_metric: 0.7014 - dice_coefficient: 0.8147 - val_loss: 0.2863 - val_accuracy: 0.9891 - val_iou_metric: 0.6296 - val_dice_coefficient: 0.7565 - lr: 0.0010
# Epoch 15/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2038 - accuracy: 0.9921 - iou_metric: 0.7226 - dice_coefficient: 0.8300
# Epoch 15: val_loss improved from 0.25813 to 0.24551, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 58s 505ms/step - loss: 0.2038 - accuracy: 0.9921 - iou_metric: 0.7226 - dice_coefficient: 0.8300 - val_loss: 0.2455 - val_accuracy: 0.9906 - val_iou_metric: 0.6746 - val_dice_coefficient: 0.7984 - lr: 0.0010
# Epoch 16/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1787 - accuracy: 0.9930 - iou_metric: 0.7518 - dice_coefficient: 0.8508
# Epoch 16: val_loss did not improve from 0.24551
# 115/115 [==============================] - 56s 484ms/step - loss: 0.1787 - accuracy: 0.9930 - iou_metric: 0.7518 - dice_coefficient: 0.8508 - val_loss: 0.2462 - val_accuracy: 0.9905 - val_iou_metric: 0.6736 - val_dice_coefficient: 0.7966 - lr: 0.0010
# Epoch 17/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1855 - accuracy: 0.9927 - iou_metric: 0.7447 - dice_coefficient: 0.8453
# Epoch 17: val_loss improved from 0.24551 to 0.24525, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 59s 516ms/step - loss: 0.1855 - accuracy: 0.9927 - iou_metric: 0.7447 - dice_coefficient: 0.8453 - val_loss: 0.2452 - val_accuracy: 0.9906 - val_iou_metric: 0.6777 - val_dice_coefficient: 0.8025 - lr: 0.0010
# Epoch 18/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1742 - accuracy: 0.9932 - iou_metric: 0.7576 - dice_coefficient: 0.8548
# Epoch 18: val_loss did not improve from 0.24525
# 115/115 [==============================] - 58s 504ms/step - loss: 0.1742 - accuracy: 0.9932 - iou_metric: 0.7576 - dice_coefficient: 0.8548 - val_loss: 0.2621 - val_accuracy: 0.9899 - val_iou_metric: 0.6554 - val_dice_coefficient: 0.7809 - lr: 0.0010
# Epoch 19/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1686 - accuracy: 0.9934 - iou_metric: 0.7650 - dice_coefficient: 0.8595
# Epoch 19: val_loss improved from 0.24525 to 0.22769, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 62s 539ms/step - loss: 0.1686 - accuracy: 0.9934 - iou_metric: 0.7650 - dice_coefficient: 0.8595 - val_loss: 0.2277 - val_accuracy: 0.9910 - val_iou_metric: 0.6963 - val_dice_coefficient: 0.8135 - lr: 0.0010
# Epoch 20/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1597 - accuracy: 0.9937 - iou_metric: 0.7761 - dice_coefficient: 0.8670
# Epoch 20: val_loss improved from 0.22769 to 0.22769, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 63s 544ms/step - loss: 0.1597 - accuracy: 0.9937 - iou_metric: 0.7761 - dice_coefficient: 0.8670 - val_loss: 0.2277 - val_accuracy: 0.9910 - val_iou_metric: 0.6971 - val_dice_coefficient: 0.8151 - lr: 0.0010
# Epoch 21/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1444 - accuracy: 0.9943 - iou_metric: 0.7946 - dice_coefficient: 0.8795
# Epoch 21: val_loss did not improve from 0.22769
# 115/115 [==============================] - 60s 521ms/step - loss: 0.1444 - accuracy: 0.9943 - iou_metric: 0.7946 - dice_coefficient: 0.8795 - val_loss: 0.2376 - val_accuracy: 0.9912 - val_iou_metric: 0.6855 - val_dice_coefficient: 0.8071 - lr: 0.0010
# Epoch 22/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1536 - accuracy: 0.9940 - iou_metric: 0.7840 - dice_coefficient: 0.8724
# Epoch 22: val_loss did not improve from 0.22769
# 115/115 [==============================] - 60s 521ms/step - loss: 0.1536 - accuracy: 0.9940 - iou_metric: 0.7840 - dice_coefficient: 0.8724 - val_loss: 0.2462 - val_accuracy: 0.9909 - val_iou_metric: 0.6781 - val_dice_coefficient: 0.8028 - lr: 0.0010
# Epoch 23/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9940 - iou_metric: 0.7842 - dice_coefficient: 0.8725
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 23: val_loss did not improve from 0.22769
# 115/115 [==============================] - 60s 519ms/step - loss: 0.1530 - accuracy: 0.9940 - iou_metric: 0.7842 - dice_coefficient: 0.8725 - val_loss: 0.2483 - val_accuracy: 0.9904 - val_iou_metric: 0.6709 - val_dice_coefficient: 0.7954 - lr: 0.0010
# Epoch 24/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1318 - accuracy: 0.9948 - iou_metric: 0.8108 - dice_coefficient: 0.8896
# Epoch 24: val_loss improved from 0.22769 to 0.21209, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 59s 513ms/step - loss: 0.1318 - accuracy: 0.9948 - iou_metric: 0.8108 - dice_coefficient: 0.8896 - val_loss: 0.2121 - val_accuracy: 0.9917 - val_iou_metric: 0.7141 - val_dice_coefficient: 0.8281 - lr: 1.0000e-04
# Epoch 25/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1182 - accuracy: 0.9953 - iou_metric: 0.8288 - dice_coefficient: 0.9010
# Epoch 25: val_loss improved from 0.21209 to 0.20925, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 58s 503ms/step - loss: 0.1182 - accuracy: 0.9953 - iou_metric: 0.8288 - dice_coefficient: 0.9010 - val_loss: 0.2092 - val_accuracy: 0.9919 - val_iou_metric: 0.7181 - val_dice_coefficient: 0.8315 - lr: 1.0000e-04
# Epoch 26/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1129 - accuracy: 0.9955 - iou_metric: 0.8357 - dice_coefficient: 0.9056
# Epoch 26: val_loss improved from 0.20925 to 0.20711, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 58s 503ms/step - loss: 0.1129 - accuracy: 0.9955 - iou_metric: 0.8357 - dice_coefficient: 0.9056 - val_loss: 0.2071 - val_accuracy: 0.9921 - val_iou_metric: 0.7209 - val_dice_coefficient: 0.8334 - lr: 1.0000e-04
# Epoch 27/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1096 - accuracy: 0.9957 - iou_metric: 0.8402 - dice_coefficient: 0.9084
# Epoch 27: val_loss improved from 0.20711 to 0.20621, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 58s 506ms/step - loss: 0.1096 - accuracy: 0.9957 - iou_metric: 0.8402 - dice_coefficient: 0.9084 - val_loss: 0.2062 - val_accuracy: 0.9921 - val_iou_metric: 0.7218 - val_dice_coefficient: 0.8340 - lr: 1.0000e-04
# Epoch 28/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1069 - accuracy: 0.9958 - iou_metric: 0.8438 - dice_coefficient: 0.9105
# Epoch 28: val_loss improved from 0.20621 to 0.20304, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 58s 505ms/step - loss: 0.1069 - accuracy: 0.9958 - iou_metric: 0.8438 - dice_coefficient: 0.9105 - val_loss: 0.2030 - val_accuracy: 0.9921 - val_iou_metric: 0.7253 - val_dice_coefficient: 0.8366 - lr: 1.0000e-04
# Epoch 29/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1048 - accuracy: 0.9959 - iou_metric: 0.8466 - dice_coefficient: 0.9123
# Epoch 29: val_loss improved from 0.20304 to 0.20203, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 58s 502ms/step - loss: 0.1048 - accuracy: 0.9959 - iou_metric: 0.8466 - dice_coefficient: 0.9123 - val_loss: 0.2020 - val_accuracy: 0.9923 - val_iou_metric: 0.7265 - val_dice_coefficient: 0.8374 - lr: 1.0000e-04
# Epoch 30/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9960 - iou_metric: 0.8509 - dice_coefficient: 0.9149
# Epoch 30: val_loss improved from 0.20203 to 0.19941, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 58s 503ms/step - loss: 0.1017 - accuracy: 0.9960 - iou_metric: 0.8509 - dice_coefficient: 0.9149 - val_loss: 0.1994 - val_accuracy: 0.9923 - val_iou_metric: 0.7297 - val_dice_coefficient: 0.8397 - lr: 1.0000e-04
# Epoch 31/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9960 - iou_metric: 0.8525 - dice_coefficient: 0.9159
# Epoch 31: val_loss improved from 0.19941 to 0.19896, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 58s 506ms/step - loss: 0.1005 - accuracy: 0.9960 - iou_metric: 0.8525 - dice_coefficient: 0.9159 - val_loss: 0.1990 - val_accuracy: 0.9924 - val_iou_metric: 0.7304 - val_dice_coefficient: 0.8404 - lr: 1.0000e-04
# Epoch 32/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9961 - iou_metric: 0.8556 - dice_coefficient: 0.9178
# Epoch 32: val_loss improved from 0.19896 to 0.19854, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 59s 512ms/step - loss: 0.0982 - accuracy: 0.9961 - iou_metric: 0.8556 - dice_coefficient: 0.9178 - val_loss: 0.1985 - val_accuracy: 0.9924 - val_iou_metric: 0.7318 - val_dice_coefficient: 0.8413 - lr: 1.0000e-04
# Epoch 33/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0967 - accuracy: 0.9962 - iou_metric: 0.8578 - dice_coefficient: 0.9191
# Epoch 33: val_loss improved from 0.19854 to 0.19840, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 59s 515ms/step - loss: 0.0967 - accuracy: 0.9962 - iou_metric: 0.8578 - dice_coefficient: 0.9191 - val_loss: 0.1984 - val_accuracy: 0.9924 - val_iou_metric: 0.7319 - val_dice_coefficient: 0.8410 - lr: 1.0000e-04
# Epoch 34/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0948 - accuracy: 0.9963 - iou_metric: 0.8605 - dice_coefficient: 0.9206
# Epoch 34: val_loss improved from 0.19840 to 0.19756, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 58s 504ms/step - loss: 0.0948 - accuracy: 0.9963 - iou_metric: 0.8605 - dice_coefficient: 0.9206 - val_loss: 0.1976 - val_accuracy: 0.9924 - val_iou_metric: 0.7327 - val_dice_coefficient: 0.8421 - lr: 1.0000e-04
# Epoch 35/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.9963 - iou_metric: 0.8625 - dice_coefficient: 0.9220
# Epoch 35: val_loss improved from 0.19756 to 0.19688, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 58s 503ms/step - loss: 0.0933 - accuracy: 0.9963 - iou_metric: 0.8625 - dice_coefficient: 0.9220 - val_loss: 0.1969 - val_accuracy: 0.9924 - val_iou_metric: 0.7335 - val_dice_coefficient: 0.8427 - lr: 1.0000e-04
# Epoch 36/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0917 - accuracy: 0.9964 - iou_metric: 0.8649 - dice_coefficient: 0.9233
# Epoch 36: val_loss improved from 0.19688 to 0.19513, saving model to model_best_checkpoint.h5
# 115/115 [==============================] - 58s 505ms/step - loss: 0.0917 - accuracy: 0.9964 - iou_metric: 0.8649 - dice_coefficient: 0.9233 - val_loss: 0.1951 - val_accuracy: 0.9925 - val_iou_metric: 0.7347 - val_dice_coefficient: 0.8431 - lr: 1.0000e-04
# Epoch 37/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0903 - accuracy: 0.9964 - iou_metric: 0.8666 - dice_coefficient: 0.9245
# Epoch 37: val_loss did not improve from 0.19513
# 115/115 [==============================] - 56s 485ms/step - loss: 0.0903 - accuracy: 0.9964 - iou_metric: 0.8666 - dice_coefficient: 0.9245 - val_loss: 0.1972 - val_accuracy: 0.9925 - val_iou_metric: 0.7330 - val_dice_coefficient: 0.8422 - lr: 1.0000e-04
# Epoch 38/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.9965 - iou_metric: 0.8686 - dice_coefficient: 0.9256
# Epoch 38: val_loss did not improve from 0.19513
# 115/115 [==============================] - 57s 496ms/step - loss: 0.0889 - accuracy: 0.9965 - iou_metric: 0.8686 - dice_coefficient: 0.9256 - val_loss: 0.1982 - val_accuracy: 0.9925 - val_iou_metric: 0.7320 - val_dice_coefficient: 0.8417 - lr: 1.0000e-04
# Epoch 39/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.9966 - iou_metric: 0.8725 - dice_coefficient: 0.9278
# Epoch 39: val_loss did not improve from 0.19513
# 115/115 [==============================] - 58s 509ms/step - loss: 0.0863 - accuracy: 0.9966 - iou_metric: 0.8725 - dice_coefficient: 0.9278 - val_loss: 0.1986 - val_accuracy: 0.9925 - val_iou_metric: 0.7323 - val_dice_coefficient: 0.8420 - lr: 1.0000e-04
# Epoch 40/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.9966 - iou_metric: 0.8733 - dice_coefficient: 0.9284
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 40: val_loss did not improve from 0.19513
# 115/115 [==============================] - 60s 518ms/step - loss: 0.0855 - accuracy: 0.9966 - iou_metric: 0.8733 - dice_coefficient: 0.9284 - val_loss: 0.1961 - val_accuracy: 0.9925 - val_iou_metric: 0.7345 - val_dice_coefficient: 0.8434 - lr: 1.0000e-04
# Epoch 41/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0836 - accuracy: 0.9967 - iou_metric: 0.8759 - dice_coefficient: 0.9300
# Epoch 41: val_loss did not improve from 0.19513
# 115/115 [==============================] - 60s 523ms/step - loss: 0.0836 - accuracy: 0.9967 - iou_metric: 0.8759 - dice_coefficient: 0.9300 - val_loss: 0.1987 - val_accuracy: 0.9925 - val_iou_metric: 0.7328 - val_dice_coefficient: 0.8428 - lr: 1.0000e-04

# %%
model = load_model('model_best_checkpoint.h5', custom_objects={'bce_dice_loss': bce_dice_loss,'iou_metric':iou_metric,'dice_coefficient':dice_coefficient}) #or compile = False

# %% [markdown]
# ### Plot graph of Dice Loss, IoU Metric, and Dice Coefficient

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 4))
t = f.suptitle('Model Performance in Segmenting Tumors', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)
epoch_list = hist.epoch

ax1.plot(epoch_list, hist.history['loss'], label='Train Dice Loss')
ax1.plot(epoch_list, hist.history['val_loss'], label='Val Dice Loss')
ax1.set_xticks(np.arange(0, epoch_list[-1], 5))
ax1.set_ylabel('Dice Loss Value');ax1.set_xlabel('Epoch');ax1.set_title('Dice Loss')
ax1.legend(loc="best");ax1.grid(color='gray', linestyle='-', linewidth=0.5)

ax2.plot(epoch_list, hist.history['dice_coefficient'], label='Train Dice Coeff')
ax2.plot(epoch_list, hist.history['val_dice_coefficient'], label='Val Dice Coeff')
ax2.set_xticks(np.arange(0, epoch_list[-1], 5))
ax2.set_ylabel('Dice Coefficient Value');ax2.set_xlabel('Epoch');ax2.set_title('Dice Coefficient')
ax2.legend(loc="best");ax2.grid(color='gray', linestyle='-', linewidth=0.5)

ax3.plot(epoch_list, hist.history['iou_metric'], label='Train IOU metric')
ax3.plot(epoch_list, hist.history['val_iou_metric'], label='Val IOU metric')
ax3.set_xticks(np.arange(0, epoch_list[-1], 5))
ax3.set_ylabel('IOU metric');ax3.set_xlabel('Epoch');ax3.set_title('IOU metric')
ax3.legend(loc="best");ax3.grid(color='gray', linestyle='-', linewidth=0.5)

# %% [markdown]
# ### Plot IoU Curve using different Thresholds

# %%
def getIOUCurve(mask_org,predicted):
  thresholds = np.linspace(0, 1, 100)
  ious = np.array([get_iou_vector(mask_org, predicted > threshold) for threshold in thresholds])
  thres_best_index = np.argmax(ious[9:-10]) + 9
  iou_best = ious[thres_best_index]
  thres_best = thresholds[thres_best_index]
  return thresholds,ious,iou_best,thres_best

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Model Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

th, ious, iou_best, th_best = getIOUCurve(Y_v,model.predict(X_v))
ax1.plot(th, ious,label="For Validation")
ax1.plot(th_best, iou_best, "xr", label="Best threshold")
ax1.set_ylabel('IOU');ax1.set_xlabel('Threshold')
ax1.set_title("Threshold vs IoU ({}, {})".format(round(th_best, 4), round(iou_best, 4)))

th, ious, iou_best, th_best = getIOUCurve(Y,model.predict(X))
ax2.plot(th, ious, label="For Training")
ax2.plot(th_best, iou_best, "xr", label="Best threshold")
ax2.set_ylabel('IOU');ax2.set_xlabel('Threshold')
ax2.set_title("Threshold vs IoU ({}, {})".format(round(th_best, 4), round(iou_best, 4)))
# Out:
# 20/20 [==============================] - 5s 228ms/step
# 154/154 [==============================] - 23s 149ms/step
# Text(0.5, 1.0, 'Threshold vs IoU (0.4444, 0.838)')

# %% [markdown]
# ### Determine IoU and Dice Coefficient for Threshold=0.5

# %%
pred_mask = model.predict(X_v)
iou_score = iou_metric(Y_v, pred_mask)
dice_coeff = dice_coefficient(Y_v, pred_mask)
print("IoU score is: ", tf.get_static_value(iou_score))
print("Dice Coefficient is: ", tf.get_static_value(dice_coeff))
# Out:
# 20/20 [==============================] - 3s 135ms/step
# IoU score is:  0.7317965644145902
# Dice Coefficient is:  0.84215665

# %% [markdown]
# ### Predict Masks

# %%
predicted_mask = pred_mask>THRESHOLD

plt.figure(figsize=(8,30))
i=1;total=10
temp = np.ones_like( Y_v[0] )
for idx in np.random.randint(0,high=X_v.shape[0],size=total):
    plt.subplot(total,3,i);i+=1
    plt.imshow( np.squeeze(X_v[idx],axis=-1), cmap='gray' )
    plt.title("MRI Image");plt.axis('off')
    
    plt.subplot(total,3,i);i+=1
    plt.imshow( np.squeeze(X_v[idx],axis=-1), cmap='gray' )
    plt.imshow( np.squeeze(temp - Y_v[idx],axis=-1), alpha=0.2, cmap='Set1' )
    plt.title("Original Mask");plt.axis('off')
    
    plt.subplot(total,3,i);i+=1
    plt.imshow( np.squeeze(X_v[idx],axis=-1), cmap='gray' )
    plt.imshow( np.squeeze(temp - predicted_mask[idx],axis=-1),  alpha=0.2, cmap='Set1' )
    plt.title("Predicted Mask");plt.axis('off')
